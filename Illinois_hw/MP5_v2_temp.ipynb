# %% [markdown]
# # Deep Q-Learning

# %% [markdown]
# Install dependencies for AI gym to run properly (shouldn't take more than a minute). If running on google cloud or running locally, only need to run once. Colab may require installing everytime the vm shuts down.

# %%
# !pip3 install gym pyvirtualdisplay
# !sudo apt-get install -y xvfb python-opengl ffmpeg

# %%
# !pip3 install --upgrade setuptools --user
# !pip3 install ez_setup 
# !pip3 install gym[atari] 
# !pip3 install gym[accept-rom-license]

# %%
import torch
print(torch.cuda.is_available())  # Should return True if CUDA is available
print(torch.version.cuda)  # Should print 11.8
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"CUDA device: {device}")  # Expected output: "cuda:0" if GPU is available
# Out:
# True
# 11.8
# CUDA device: cuda

# %% [markdown]
# For this assignment we will implement the Deep Q-Learning algorithm with Experience Replay as described in breakthrough paper __"Playing Atari with Deep Reinforcement Learning"__. We will train an agent to play the famous game of __Breakout__.

# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

import sys
# import gym
import gymnasium as gym
import ale_py
import pylab
import random
import numpy as np
from collections import deque
from datetime import datetime
from copy import deepcopy
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch.autograd import Variable
from utils import *
from model import DQN, DQN_LSTM
from config import *
from checkpoint import *
import pickle
import os

import matplotlib.pyplot as plt

# %%
# Function to create metadata for checkpointing puposes
def create_metadata(agent, global_episode, global_frame, eval_rewards, rewards, episodes, last_10_ep_losses, loss_tracker):
    return {
    'global_episode': global_episode,
    'global_frame': global_frame,
    'batch_size': BATCH_SIZE,
    'sch_gamma': scheduler_gamma,
    'sch_step_size': scheduler_step_size,
    'tgt_update_freq': update_target_network_frequency,
    'memory capacity': Memory_capacity,  
    'explore steps': EXPLORE_STEPS, 
    'epsilon_decay_rate': agent.epsilon_decay_rate,
    'sticky_action_prob': sticky_action_prob,
    'eval_rewards': eval_rewards,
    'rewards': rewards,
    'episodes': episodes,
    'last_10_ep_losses': last_10_ep_losses,
    'loss_tracker': loss_tracker

    }

# %%
import sys
import os

class TeeLogger:
    def __init__(self, filepath):
        self.original_stdout = sys.__stdout__  # raw terminal (useful fallback)
        self.ipython_stdout = sys.stdout       # the notebook's visible output
        self.log = open(filepath, "w")

    def write(self, message):
        self.ipython_stdout.write(message)
        self.log.write(message)
        self.flush()

    def flush(self):
        self.ipython_stdout.flush()
        self.log.flush()

    def close(self):
        self.log.close()

# %% [markdown]
# ## Understanding the environment

# %% [markdown]
# Unlike the UIlliniois assigment this code is based on, I will be using the Gymnasium (https://github.com/farama-Foundation/gymnasium) and the Atari Learning Environment (ALE, link here: https://ale.farama.org/), rather than gym, which has been deprecated.  We will still be playing Breakout on Atari.
#
# To replecate BreakoutDeterministic-v4, as a starting point we'll use ALE/Breakout-v5 with frameskip=4, no "sticky actions" (i.e. deterministic actions), and a limited action space of NOOP, FIRE, LEFT, RIGHT.  However we won't be training on FIRE, instead we will ensure FIRE only happens when the game first starts and when a ball/life is lost.

# %%
# env = gym.make('BreakoutDeterministic-v4')
env = gym.make('ALE/Breakout-v5', frameskip=4, repeat_action_probability=0.0, full_action_space=False)  # Use equivalent parameters to BreakoutDeterministic-v4
state = env.reset()

# %%
number_lives = find_max_lives(env)
state_size = env.observation_space.shape
action_size = 3 #noop, left, and right.  Fire ball (action 1) is not trained

# %% [markdown]
# ## Creating a DQN Agent

# %% [markdown]
# Here we create a DQN Agent. This agent is defined in the __agent.py__. The corresponding neural network is defined in the __model.py__. Once you've created a working DQN agent, use the code in agent.py to create a double DQN agent in __agent_double.py__. Set the flag "double_dqn" to True to train the double DQN agent.
#
# __Evaluation Reward__ : The average reward received in the past 100 episodes/games.
#
# __Frame__ : Number of frames processed in total.
#
# __Memory Size__ : The current size of the replay memory.

# %% [markdown]
# ### Create Replay Memory Pickle

# %%
# # # ### Pickle Replay Creator ###
# from gymnasium.wrappers import RecordVideo
# from config import *


# mem_name = 'Buffer_for_testing_using_Run13_new_get_frame'

# #create fresh environment
# env = gym.make('ALE/Breakout-v5', frameskip=4, repeat_action_probability=sticky_action_prob, full_action_space=False, render_mode='rgb_array')
# # env = RecordVideo(env, video_folder="./videos", episode_trigger=lambda ep: ep % 20 == 0)  

# # Choose whether to use double DQN
# double_dqn = False # set to True if using double DQN agent
# if double_dqn:
#     from agent_double import Agent
# else:
#     from agent import Agent

# # print("Instantiating agent")
# agent = Agent(action_size)
# agent.load_policy_net("./save_model/run13/good_Run13_StdDQN_750K_frames_imprvdBatching_2477_eps.pth")
# agent.target_net.load_state_dict(agent.policy_net.state_dict())
# agent.epsilon = 0.1

# frame = 0   
# evaluation_reward = deque(maxlen=evaluation_reward_length)
# rewards, episodes = [], []
# best_eval_reward = 0
# exit_flag = False

# for e in range(EPISODES):
#     done = False
#     score = 0

#     history = np.zeros([5, 84, 84], dtype=np.uint8)
#     step = 0
#     state, _ = env.reset()
#     next_state = state
#     life = number_lives
#     fire_ready = True

#     get_init_state(history, state, HISTORY_SIZE)

#     while not done:
#         step += 1
#         frame += 1

#         # Selet Action (with robust check for FIRE action)
#         if fire_ready:
#             next_state, force_done = reset_after_life_loss(env, history)
#             if force_done:
#                 break
#             action = 1
#             fire_ready = False
#         else:
#             trainable_action = agent.get_action(np.float32(history[:4, :, :]) / 255.)
#             action = TRAINABLE_ACTIONS[trainable_action]

#         state = next_state
#         next_state, reward, terminations, truncations, info = env.step(action)  
#         done = truncations or terminations
#         frame_next_state = get_frame(next_state)
#         frame_for_buffer = new_get_frame(next_state)

#         history[4, :, :] = frame_next_state
#         lost_life = check_live(life, info['lives'])  #check if the agent has lost a life

#         if lost_life:
#             fire_ready = True

#         life = info['lives']
#         r = reward

#         # Store the transition in memory if it was not a FIRE action
#         if action in TRAINABLE_ACTIONS:
#             trainable_index = TRAINABLE_ACTIONS.index(action)
#             agent.memory.push(deepcopy(frame_for_buffer), trainable_index, r, lost_life)
#         # When replay buffer is filled save to pickle and break
#         if len(agent.memory) == train_frame:
#             print(f"Memory filled, saving pickle file") 
#             agent.save_replay_buffer(mem_name, frame)
#             exit_flag = True
#             break 
#         score += reward
#         history[:4, :, :] = history[1:, :, :]  # shift history by one erasing oldest frame

#         if done:
#             fire_ready = True
#             evaluation_reward.append(score)
#             rewards.append(np.mean(evaluation_reward))  # record moving average of last evaluation_reward_length episodes
#             episodes.append(e)

#             # print episode information 
#             if e % 1 == 0:
#                 print("episode:", e, "  score:", score, "  memory length:",
#                   len(agent.memory), "  epsilon:", agent.epsilon, "  steps:", step,
#                   "  lr:", agent.optimizer.param_groups[0]['lr'], 
#                   "  evaluation reward:", np.mean(evaluation_reward))
#     if exit_flag:
#         break
# Out:
# DQN Agent initialized
# No replay buffer path provided. Creating new empty buffer.
# c:\Users\rbisk\Dropbox\GMU\cs747 Deep Learning\Final_Project\Illinois_hw\agent.py:60: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.policy_net.load_state_dict(torch.load(path))
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 62
#      60 next_state, reward, terminations, truncations, info = env.step(action)
#      61 done = truncations or terminations
# ---> 62 frame_next_state = get_frame(next_state)
#      63 frame_for_buffer = new_get_frame(next_state)
#      65 history[4, :, :] = frame_next_state
#
# NameError: name 'get_frame' is not defined

# %%
# # Start logging
# log_file = "./test_log.txt"
# tee = TeeLogger(log_file)
# sys.stdout = tee
# sys.stderr = tee

# print(f"Logging started. Output will be written to both notebook and {log_file}")

# %%
# # Stop logging safely
# sys.stdout = tee.original_stdout
# sys.stderr = tee.original_stdout
# tee.close()

# print("This goes only to the notebook now.")

# %% [markdown]
# ### Main Training Loop

# %% [markdown]
# In this training loop, we do not render the screen because it slows down training signficantly. To watch the agent play the game, run the code in next section "Visualize Agent Performance"

# %%
## Setup Run Name and Memory Paths ##
mem_path = None
# mem_path = './checkpoints/Run1_DQN_Serial_20pctExplore_and_Sticky_100000_replay_buffer.pkl'
# mem_path = './checkpoints/Buffer_for_testing_using_Run5_50K_replay_buffer.pkl'
# mem_path = './checkpoints/Buffer_for_testing_using_Run13_new_get_frame_100974_replay_buffer.pkl'
seed = 83

# %%
# log_dir = f"./logs/run{run_num}"
# os.makedirs(log_dir, exist_ok=True)
# log_file = os.path.join(log_dir, f"{run_name}_output.log")
# tee = TeeLogger(log_file)
# sys.stdout = tee
# sys.stderr = tee

# print(f"Logging started. Output will be written to both notebook and {log_file}")

# %%
set_seed(seed)

run_num = "12"
name = "DDQN_750K_frames_imprvdBatching"
run_name = "Run"+ str(run_num) + "_" + name

from config import *
from IPython.display import clear_output
from gymnasium.wrappers import RecordVideo

# choose which Agent to use
# from agent_dbl_timediff import Agent
from agent_double import Agent

#create fresh environment
env = gym.make('ALE/Breakout-v5', frameskip=4, repeat_action_probability=sticky_action_prob, full_action_space=False, render_mode='rgb_array')  # Use equivalent parameters to BreakoutDeterministic-v4

# setup video recording
def video_trigger(_):
    if len(episodes) == 0:
        return False
    else:
        curr_ep = episodes[-1]
        return (curr_ep > 99 and curr_ep % 100 == 0) 

video_path = f"./videos/run{run_num}"
if not os.path.exists(video_path):
    os.makedirs(video_path)
env = RecordVideo(env, video_folder=video_path, episode_trigger=video_trigger)


print(f"Starting run {run_name}")
train_interval = 1
    
evaluation_reward = deque(maxlen=evaluation_reward_length)
rewards, episodes = [], []
reward = 0
best_eval_reward = curr_mean_reward = last_save_reward = 0

#initialize trackers
## LOSS TRACKERS ##
losses_window = deque(maxlen=10)
loss_history = []
episode_losses = []
loss = mean_loss = 0

# ## Q-VALUE TRACKERS ##
episode_q_means = []
episode_q_maxs = []
episode_q_mins = []
q_mean_window = deque(maxlen=10)
q_max_window = deque(maxlen=10)
q_min_window = deque(maxlen=10)
q_stats_history = {
    'mean': [],
    'max': [],
    'min': [],
    'episode': []
}

# Epsilon Bump Control Variables
plateau_patience = 300
episodes_since_improvement = 0
epsilon_bump = 0.15  # amount to re-increase epsilon
soonest_bump = 2000  # earliest episode to apply epsilon bump

frame = 0
ep_start = 0
training_started_flg = False

print("Instantiating agent")
agent = Agent(action_size, mem_path)
# agent = Agent(action_size)

#########################
#### LOAD CHECKPOINT ####
# metadata = agent.load_checkpoint("Run8_Stdized_DDQN_750K_frames", 2999)  #Edit episode number
# frame = metadata['global_frame']
# agent.load_replay_buffer("Run8_Stdized_DDQN_750K_frames", 711354)
# ep_start = metadata['global_episode']
# evaluation_reward = metadata['eval_rewards']
# rewards = metadata['rewards']    
# episodes = metadata['episodes']
# losses_window = metadata['last_10_ep_losses']
# loss_history = metadata['loss_tracker']
# training_started_flg = True
########################


start_train_immediate = True
frame_max = 750_000

for e in range(ep_start, EPISODES):
    #limit number of frames for consistent testing
    if frame >= frame_max:
        break

    done = False
    score = 0
    episode_losses = []
    history = np.zeros([5, 84, 84], dtype=np.uint8)
    step = 0
    state, _ = env.reset()
    next_state = state
    life = number_lives
    fire_ready = True
    no_reward_steps = 0

    get_init_state(history, state, HISTORY_SIZE)

    while not done:
        
        #limit number of frames for consitent testing
        if frame >= frame_max:
            break

        step += 1
        frame += 1

        # Selet Action (with robust check for FIRE action)
        if fire_ready:
            next_state, force_done = reset_after_life_loss(env, history)
            if force_done:
                break
            action = 1
            fire_ready = False
        else:
            trainable_action = agent.get_action(np.float32(history[:4, :, :]) / 255.)
            action = TRAINABLE_ACTIONS[trainable_action]

        # Step the environment
        state = next_state
        next_state, reward, terminations, truncations, info = env.step(action)  
        done = truncations or terminations
        
        # Failsafe to force reset if no reward for 3000 steps (prevents agent from getting stuck)
        stuck_limit = 3000
        if no_reward_steps > stuck_limit:
            done = True
            print(f"[WARNING] No reward for {stuck_limit} steps, forcing reset | ", "Episode:", e, "  Frame:", frame, ) 
             
        frame_next_state = get_frame(next_state)
             
        # append next state to history
        history[4, :, :] = frame_next_state
        
        # life handling
        lost_life = check_live(life, info['lives'])  #check if the agent has lost a life
        if lost_life:
            fire_ready = True
        life = info['lives']
        
        r = reward
        if r == 0:
            no_reward_steps += 1
        else:
            no_reward_steps = 0 

        # Store the transition in replay buffer if it was not a FIRE action
        if action in TRAINABLE_ACTIONS:
            trainable_index = TRAINABLE_ACTIONS.index(action)
            agent.memory.push(deepcopy(frame_next_state), trainable_index, r, lost_life)
        
        # Start training after random sample generation
        if frame == train_frame or (start_train_immediate and frame == 1):
            print("Starting training")
            training_started_flg = True
        if(frame >= train_frame or start_train_immediate): 
            if frame % train_interval == 0: # Use adaptive training interval
                loss, q_stats = agent.train_policy_net()
                episode_losses.append(loss)
                episode_q_means.append(q_stats['q_mean'])
                episode_q_maxs.append(q_stats['q_max'])
                episode_q_mins.append(q_stats['q_min'])
            # Update the target network
            if (frame % (train_interval * update_target_network_frequency)) == 0:
                agent.update_target_net()
                print("Target network updated at frame: ", frame)
        
        # Update score and history
        score += reward
        history[:4, :, :] = history[1:, :, :]  # shift history by one erasing oldest frame
            
        if done:
            fire_ready = True
            evaluation_reward.append(score)            
            episodes.append(e)

            # print episode information every X episodes
            if e % 5 == 0:
                print("episode:", e, "  frame:", frame, "  score:", score, "  memory length:",
                  len(agent.memory), "  epsilon:", round(agent.epsilon, 5), 
                  "  steps:", step, "  lr:", agent.optimizer.param_groups[0]['lr'], 
                  "  reward MA:", round(np.mean(evaluation_reward), 3), 
                  "  model train updates:", len(episode_losses), "  mean loss:", round(mean_loss, 5))

            
            if training_started_flg:

                rewards.append(np.mean(evaluation_reward))  # record moving average of last evaluation_reward_length episodes

                # # adapt training interval to agent performance
                # if np.mean(evaluation_reward) < 8:
                #     train_interval = 4
                # elif np.mean(evaluation_reward) < 15:
                #     train_interval = 2
                # else:
                #     train_interval = 1
            
                # save rolling loss everages every X episodes
                if episode_losses:
                    mean_loss = sum(episode_losses) / len(episode_losses)
                    losses_window.append(mean_loss)
                    if e > 9 and e % 10 == 0:
                        loss_history.append((np.mean(losses_window), e))

                # save rolling Q-score averages every X episodes
                # q_mean_window.append(np.mean(episode_q_means))
                # q_max_window.append(np.mean(episode_q_maxs))
                # q_min_window.append(np.mean(episode_q_mins))
                q_stats_history['mean'].append(np.mean(episode_q_means))
                q_stats_history['max'].append(np.mean(episode_q_maxs))
                q_stats_history['min'].append(np.mean(episode_q_mins))
                q_stats_history['episode'].append(e)
                episode_q_means = []
                episode_q_maxs = []
                episode_q_mins = []


                # plot the rewards every X episodes
                if e > 0 and e % 50 == 0:
                    # clear_output(wait=True)
                    pylab.plot(episodes, rewards, 'b')
                    pylab.xlabel('Episode #')
                    pylab.ylabel('Rolling Mean Episode Scores') 
                    pylab.title('Breakout: DDQN Scores')
                    plot_path = f"./save_graph/run{run_num}/{run_name}_ep{e}_scores.png"
                    os.makedirs(os.path.dirname(plot_path), exist_ok=True)
                    pylab.savefig(plot_path)
                    print(f"[SAVED PLOT] {plot_path}")
                    pylab.show()
                    pylab.close()
                
                # every X episodes, plot the mean losses
                if e > 0 and e % 50 == 0:
                    x = [entry[1] for entry in loss_history]
                    y = [entry[0] for entry in loss_history]
                    pylab.plot(x, y, 'r')
                    pylab.xlabel('Episode #')
                    pylab.ylabel('Rolling Mean Loss per Episode') 
                    pylab.title('Breakout: DDQN Loss')
                    plot_path = f"./save_graph/run{run_num}/{run_name}_ep{e}_losses.png"
                    os.makedirs(os.path.dirname(plot_path), exist_ok=True)
                    pylab.savefig(plot_path)
                    print(f"[SAVED PLOT] {plot_path}")
                    pylab.show()
                    pylab.close()

                # plot Q-value statistics every X episodes
                if e > 0 and e % 25 == 0:
                    pylab.plot(q_stats_history['episode'], q_stats_history['mean'], label='Q-Mean')
                    pylab.plot(q_stats_history['episode'], q_stats_history['max'], label='Q-Max')
                    pylab.plot(q_stats_history['episode'], q_stats_history['min'], label='Q-Min')
                    pylab.xlabel('Episode #')
                    pylab.ylabel('Q-Value')
                    pylab.title('Rolling Q-Value Statistics')
                    pylab.legend()
                    plot_path = f"./save_graph/run{run_num}/{run_name}_ep{e}_Qstats.png"
                    os.makedirs(os.path.dirname(plot_path), exist_ok=True)
                    pylab.savefig(plot_path)
                    print(f"[SAVED PLOT] {plot_path}")
                    pylab.show()
                    pylab.close()

                # Checkpoint the training process every X episodes 
                if e > 0 and e % 250 == 0:
                    metadata = create_metadata(agent, e, frame, evaluation_reward, rewards, episodes, losses_window, loss_history)
                    agent.save_checkpoint(metadata, run_name, e)
                # if e > 0 and e % 500 == 0:
                #     agent.save_replay_buffer(run_name, frame)

                # Check if reward has improved
                curr_mean_reward = np.mean(evaluation_reward)
                if curr_mean_reward > best_eval_reward:
                    best_eval_reward = curr_mean_reward
                    episodes_since_improvement = 0
                else:
                    episodes_since_improvement += 1
                
                # save model if it is good
                if curr_mean_reward > 8 and curr_mean_reward > (1.05 * last_save_reward):
                    model_path = f"./save_model/run{run_num}/good_{run_name}_{e}_eps.pth"
                    os.makedirs(os.path.dirname(model_path), exist_ok=True)
                    torch.save(agent.policy_net.state_dict(), model_path)
                    print(f"[SAVED MODEL] {model_path}")
                    last_save_reward = curr_mean_reward
               
                # # # Apply epsilon bump if plateauing
                # if e > soonest_bump and episodes_since_improvement >= plateau_patience:
                #     if agent.epsilon < agent.epsilon_max:
                #         agent.epsilon = min(agent.epsilon + epsilon_bump, agent.epsilon_max)
                #         print(f"[BUMP] Epsilon bumped to {agent.epsilon:.4f} after {plateau_patience} stagnant episodes.")
                #     episodes_since_improvement = 0  # Reset counter after bump



# Checkpoint the model at the end of training loop
metadata = create_metadata(agent, e, frame, evaluation_reward, rewards, episodes, losses_window, loss_history)
agent.save_checkpoint(metadata, run_name, e)
agent.save_replay_buffer(run_name, frame)

print("Training complete")
# Out:
# c:\Users\rbisk\anaconda3\envs\gym\lib\site-packages\gymnasium\wrappers\rendering.py:283: UserWarning: WARN: Overwriting existing videos at c:\Users\rbisk\Dropbox\GMU\cs747 Deep Learning\Final_Project\Illinois_hw\videos\run12 folder (try specifying a different `video_folder` for the `RecordVideo` wrapper if this is not desired)
#   logger.warn(
# Starting run Run12_DDQN_750K_frames_imprvdBatching
# Instantiating agent
# Double DQN Agent initialized
# Replay buffer loaded from './checkpoints/Buffer_for_testing_using_Run5_50K_replay_buffer.pkl' with size 50000
# Starting training
# episode: 0   frame: 120   score: 0.0   memory length: 50115   epsilon: 0.99978   steps: 120   lr: 0.0001   reward MA: 0.0   model train updates: 120   mean loss: 0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[55], line 170
#     168 if(frame >= train_frame or start_train_immediate):
#     169     if frame % train_interval == 0: # Use adaptive training interval
# --> 170         loss, q_stats = agent.train_policy_net()
#     171         episode_losses.append(loss)
#     172         episode_q_means.append(q_stats['q_mean'])
#
# KeyboardInterrupt:

# %%
from config import *

set_seed(seed)
run_num = "16"
name = "StdDQN_750Kfr_timediff_new_get_frame_PER"
run_name = "Run"+ str(run_num) + "_" + name


from config import *
from IPython.display import clear_output
from gymnasium.wrappers import RecordVideo

# choose which Agent to use
from agent_timediff import Agent

#create fresh environment
env = gym.make('ALE/Breakout-v5', frameskip=4, repeat_action_probability=sticky_action_prob, full_action_space=False, render_mode='rgb_array')  # Use equivalent parameters to BreakoutDeterministic-v4

# setup video recording
def video_trigger(_):
    if len(episodes) == 0:
        return False
    else:
        curr_ep = episodes[-1]
        return (curr_ep > 99 and curr_ep % 100 == 0) 

video_path = f"./videos/run{run_num}"
if not os.path.exists(video_path):
    os.makedirs(video_path)
env = RecordVideo(env, video_folder=video_path, episode_trigger=video_trigger)


print(f"Starting run {run_name}")
train_interval = 1
    
evaluation_reward = deque(maxlen=evaluation_reward_length)
rewards, episodes = [], []
reward = 0
best_eval_reward = curr_mean_reward = last_save_reward = 0

#initialize trackers
## LOSS TRACKERS ##
losses_window = deque(maxlen=10)
loss_history = []
episode_losses = []
loss = mean_loss = 0

# ## Q-VALUE TRACKERS ##
episode_q_means = []
episode_q_maxs = []
episode_q_mins = []
q_mean_window = deque(maxlen=10)
q_max_window = deque(maxlen=10)
q_min_window = deque(maxlen=10)
q_stats_history = {
    'mean': [],
    'max': [],
    'min': [],
    'episode': []
}

# Epsilon Bump Control Variables
plateau_patience = 300
episodes_since_improvement = 0
epsilon_bump = 0.15  # amount to re-increase epsilon
soonest_bump = 2000  # earliest episode to apply epsilon bump

frame = 0
ep_start = 0
training_started_flg = False

print("Instantiating agent")
agent = Agent(action_size, mem_path)
# agent = Agent(action_size)

#########################
#### LOAD CHECKPOINT ####
# metadata = agent.load_checkpoint("Run8_Stdized_DDQN_750K_frames", 2999)  #Edit episode number
# frame = metadata['global_frame']
# agent.load_replay_buffer("Run8_Stdized_DDQN_750K_frames", 711354)
# ep_start = metadata['global_episode']
# evaluation_reward = metadata['eval_rewards']
# rewards = metadata['rewards']    
# episodes = metadata['episodes']
# losses_window = metadata['last_10_ep_losses']
# loss_history = metadata['loss_tracker']
# training_started_flg = True
########################


start_train_immediate = False
frame_max = 800_000
e = ep_start

while e < EPISODES:
    #limit number of frames for consistent testing
    if frame >= frame_max:
        break

    done = False
    score = 0
    episode_losses = []
    history = np.zeros([5, 84, 84], dtype=np.uint8)
    step = 0
    state, _ = env.reset()
    next_state = state
    life = number_lives
    fire_ready = True
    no_reward_steps = 0

    get_init_state(history, state, HISTORY_SIZE)

    while not done:
        
        #limit number of frames for consitent testing
        if frame >= frame_max:
            break

        step += 1
        frame += 1

        # Selet Action (with robust check for FIRE action)
        if fire_ready:  
            next_state, force_done = reset_after_life_loss(env, history)
            if force_done:
                break
            action = 1
            fire_ready = False
        else:
            trainable_action = agent.get_action(np.float32(history[:4, :, :]) / 255.)
            action = TRAINABLE_ACTIONS[trainable_action]

        # Step the environment
        state = next_state
        next_state, reward, terminations, truncations, info = env.step(action)  
        done = truncations or terminations
        
        # Failsafe to force reset if no reward for 3000 steps (prevents agent from getting stuck)
        stuck_limit = 3000
        if no_reward_steps > stuck_limit:
            done = True
            print(f"[WARNING] No reward for {stuck_limit} steps, forcing reset | ", "Episode:", e, "  Frame:", frame, ) 
             
        frame_next_state = new_get_frame(next_state)
             
        # append next state to history
        history[4, :, :] = frame_next_state
        
        # life handling
        lost_life = check_live(life, info['lives'])  #check if the agent has lost a life
        if lost_life:
            fire_ready = True
        life = info['lives']
        
        r = reward
        if r == 0:
            no_reward_steps += 1
        else:
            no_reward_steps = 0 

        # Store the transition in replay buffer if it was not a FIRE action
        if action in TRAINABLE_ACTIONS:
            trainable_index = TRAINABLE_ACTIONS.index(action)
            agent.memory.push(deepcopy(frame_next_state), trainable_index, r, lost_life)
        
        # Start training after random sample generation
        if frame == train_frame or (start_train_immediate and frame == 1):
            print("Starting training")
            training_started_flg = True
            e = ep_start  #reset episode counter when training starts
        if(training_started_flg): 
            if frame % train_interval == 0: # Use adaptive training interval
                loss, q_stats = agent.train_policy_net()
                episode_losses.append(loss)
                episode_q_means.append(q_stats['q_mean'])
                episode_q_maxs.append(q_stats['q_max'])
                episode_q_mins.append(q_stats['q_min'])
            # Update the target network
            if (frame % (train_interval * update_target_network_frequency)) == 0:
                agent.update_target_net()
                print("Target network updated at frame: ", frame)
        
        # Update score and history
        score += reward
        history[:4, :, :] = history[1:, :, :]  # shift history by one erasing oldest frame
            
        if done:
            e += 1
            fire_ready = True
            evaluation_reward.append(score)            
            

            # print episode information every X episodes
            if e % 1 == 0:
                print("episode:", e, "  frame:", frame, "  score:", score, "  memory length:",
                  len(agent.memory), "  epsilon:", round(agent.epsilon, 5), 
                  "  steps:", step, "  lr:", agent.optimizer.param_groups[0]['lr'], 
                  "  reward MA:", round(np.mean(evaluation_reward), 3), 
                  "  mean loss:", round(mean_loss, 5), "  mean max Q:", round(np.mean(episode_q_maxs), 4))
                #   "  latest step Q max:", round(q_stats['q_max'], 4))


            
            if training_started_flg:

                episodes.append(e)
                rewards.append(np.mean(evaluation_reward))  # record moving average of last evaluation_reward_length episodes

                # # adapt training interval to agent performance
                # if np.mean(evaluation_reward) < 8:
                #     train_interval = 4
                # elif np.mean(evaluation_reward) < 15:
                #     train_interval = 2
                # else:
                #     train_interval = 1

                ## DEBUG ##
                # Check TD-error distribution in Replay Buffer
                if e>0 and e % 100 == 0:
                    agent.memory.log_td_error_distribution()

                # save rolling loss everages every X episodes
                if episode_losses:
                    mean_loss = sum(episode_losses) / len(episode_losses)
                    losses_window.append(mean_loss)
                    if e > 9 and e % 10 == 0:
                        loss_history.append((np.mean(losses_window), e))

                # save rolling Q-score stat averages
                q_mean_window.append(np.mean(episode_q_means))
                q_max_window.append(np.mean(episode_q_maxs))
                q_min_window.append(np.mean(episode_q_mins))
                q_stats_history['mean'].append(np.mean(q_mean_window))
                q_stats_history['max'].append(np.mean(q_max_window))
                q_stats_history['min'].append(np.mean(q_min_window))
                q_stats_history['episode'].append(e)
                episode_q_means = []
                episode_q_maxs = []
                episode_q_mins = []

                # plot the rewards every X episodes
                if e > 0 and e % 50 == 0:
                    # clear_output(wait=True)
                    pylab.plot(episodes, rewards, 'b')
                    pylab.xlabel('Episode #')
                    pylab.ylabel('Rolling Mean Episode Scores') 
                    pylab.title('DQN w Diff Frames & Cropped Scoreboard \n Scores')
                    plot_path = f"./save_graph/run{run_num}/{run_name}_ep{e}_scores.png"
                    os.makedirs(os.path.dirname(plot_path), exist_ok=True)
                    pylab.savefig(plot_path)
                    print(f"[SAVED PLOT] {plot_path}")
                    pylab.show()
                    pylab.close()
                
                # every X episodes, plot the mean losses
                if e > 0 and e % 50 == 0:
                    x = [entry[1] for entry in loss_history]
                    y = [entry[0] for entry in loss_history]
                    pylab.plot(x, y, 'r')
                    pylab.xlabel('Episode #')
                    pylab.ylabel('Rolling Mean Loss per Episode') 
                    pylab.title('DQN w Diff Frames & Cropped Scoreboard \n Loss')
                    plot_path = f"./save_graph/run{run_num}/{run_name}_ep{e}_losses.png"
                    os.makedirs(os.path.dirname(plot_path), exist_ok=True)
                    pylab.savefig(plot_path)
                    print(f"[SAVED PLOT] {plot_path}")
                    pylab.show()
                    pylab.close()

                # plot Q-value statistics every X episodes
                if e > 0 and e % 25 == 0:
                    pylab.plot(q_stats_history['episode'], q_stats_history['mean'], label='Q-Mean')
                    pylab.plot(q_stats_history['episode'], q_stats_history['max'], label='Q-Max')
                    pylab.plot(q_stats_history['episode'], q_stats_history['min'], label='Q-Min')
                    pylab.xlabel('Episode #')
                    pylab.ylabel('Q-Value')
                    pylab.title('Avg per Episode Q-Value Stats')
                    pylab.legend(loc='upper left')
                    plot_path = f"./save_graph/run{run_num}/{run_name}_ep{e}_Qstats.png"
                    os.makedirs(os.path.dirname(plot_path), exist_ok=True)
                    pylab.savefig(plot_path)
                    print(f"[SAVED PLOT] {plot_path}")
                    pylab.show()
                    pylab.close()


                    ## DEBUG ##
                    print(f"[PLOT DEBUG] Last 5 q_means: {q_stats_history['mean'][-5:]}")

                # Checkpoint the training process every X episodes 
                if e > 0 and frame % 50_000 == 0:
                    metadata = create_metadata(agent, e, frame, evaluation_reward, rewards, episodes, losses_window, loss_history)
                    agent.save_checkpoint(metadata, run_name, e)
                if e > 0 and frame % 250_000 == 0:
                    agent.save_replay_buffer(run_name, frame)

                # Check if reward has improved
                curr_mean_reward = np.mean(evaluation_reward)
                if curr_mean_reward > best_eval_reward:
                    best_eval_reward = curr_mean_reward
                    episodes_since_improvement = 0
                else:
                    episodes_since_improvement += 1
                
                # save model if it is good
                if curr_mean_reward > 8 and curr_mean_reward > (1.05 * last_save_reward):
                    model_path = f"./save_model/run{run_num}/good_{run_name}_{e}_eps.pth"
                    os.makedirs(os.path.dirname(model_path), exist_ok=True)
                    torch.save(agent.policy_net.state_dict(), model_path)
                    print(f"[SAVED MODEL] {model_path}")
                    last_save_reward = curr_mean_reward
               
                # # # Apply epsilon bump if plateauing
                # if e > soonest_bump and episodes_since_improvement >= plateau_patience:
                #     if agent.epsilon < agent.epsilon_max:
                #         agent.epsilon = min(agent.epsilon + epsilon_bump, agent.epsilon_max)
                #         print(f"[BUMP] Epsilon bumped to {agent.epsilon:.4f} after {plateau_patience} stagnant episodes.")
                #     episodes_since_improvement = 0  # Reset counter after bump



# Checkpoint the model at the end of training loop
metadata = create_metadata(agent, e, frame, evaluation_reward, rewards, episodes, losses_window, loss_history)
agent.save_checkpoint(metadata, run_name, e)
agent.save_replay_buffer(run_name, frame)

print("Training complete")
# Out:
# Starting run Run16_StdDQN_750Kfr_timediff_new_get_frame_PER
# Instantiating agent
# Standard DQN Agent w time diffs initialized
# No replay buffer path provided. Creating new empty buffer.
# episode: 1   frame: 120   score: 0.0   memory length: 115   epsilon: 1.0   steps: 120   lr: 0.0005   reward MA: 0.0   mean loss: 0   mean max Q: nan
# episode: 2   frame: 240   score: 0.0   memory length: 230   epsilon: 1.0   steps: 120   lr: 0.0005   reward MA: 0.0   mean loss: 0   mean max Q: nan
# episode: 3   frame: 360   score: 0.0   memory length: 345   epsilon: 1.0   steps: 120   lr: 0.0005   reward MA: 0.0   mean loss: 0   mean max Q: nan
# episode: 4   frame: 480   score: 0.0   memory length: 460   epsilon: 1.0   steps: 120   lr: 0.0005   reward MA: 0.0   mean loss: 0   mean max Q: nan
# episode: 5   frame: 600   score: 0.0   memory length: 575   epsilon: 1.0   steps: 120   lr: 0.0005   reward MA: 0.0   mean loss: 0   mean max Q: nan
# episode: 6   frame: 720   score: 0.0   memory length: 690   epsilon: 1.0   steps: 120   lr: 0.0005   reward MA: 0.0   mean loss: 0   mean max Q: nan
# episode: 7   frame: 840   score: 0.0   memory length: 805   epsilon: 1.0   steps: 120   lr: 0.0005   reward MA: 0.0   mean loss: 0   mean max Q: nan
# episode: 8   frame: 960   score: 0.0   memory length: 920   epsilon: 1.0   steps: 120   lr: 0.0005   reward MA: 0.0   mean loss: 0   mean max Q: nan
# episode: 9   frame: 1137   score: 2.0   memory length: 1092   epsilon: 1.0   steps: 177   lr: 0.0005   reward MA: 0.222   mean loss: 0   mean max Q: nan
# episode: 10   frame: 1412   score: 4.0   memory length: 1362   epsilon: 1.0   steps: 275   lr: 0.0005   reward MA: 0.6   mean loss: 0   mean max Q: nan
# episode: 11   frame: 1532   score: 0.0   memory length: 1477   epsilon: 1.0   steps: 120   lr: 0.0005   reward MA: 0.545   mean loss: 0   mean max Q: nan
# episode: 12   frame: 1652   score: 0.0   memory length: 1592   epsilon: 1.0   steps: 120   lr: 0.0005   reward MA: 0.5   mean loss: 0   mean max Q: nan
# episode: 13   frame: 1830   score: 2.0   memory length: 1765   epsilon: 1.0   steps: 178   lr: 0.0005   reward MA: 0.615   mean loss: 0   mean max Q: nan
# episode: 14   frame: 1950   score: 0.0   memory length: 1880   epsilon: 1.0   steps: 120   lr: 0.0005   reward MA: 0.571   mean loss: 0   mean max Q: nan
# episode: 15   frame: 2098   score: 1.0   memory length: 2023   epsilon: 1.0   steps: 148   lr: 0.0005   reward MA: 0.6   mean loss: 0   mean max Q: nan
# episode: 16   frame: 2218   score: 0.0   memory length: 2138   epsilon: 1.0   steps: 120   lr: 0.0005   reward MA: 0.562   mean loss: 0   mean max Q: nan
# episode: 17   frame: 2366   score: 1.0   memory length: 2281   epsilon: 1.0   steps: 148   lr: 0.0005   reward MA: 0.588   mean loss: 0   mean max Q: nan
# episode: 18   frame: 2514   score: 1.0   memory length: 2424   epsilon: 1.0   steps: 148   lr: 0.0005   reward MA: 0.611   mean loss: 0   mean max Q: nan
# episode: 19   frame: 2634   score: 0.0   memory length: 2539   epsilon: 1.0   steps: 120   lr: 0.0005   reward MA: 0.579   mean loss: 0   mean max Q: nan
# episode: 20   frame: 2754   score: 0.0   memory length: 2654   epsilon: 1.0   steps: 120   lr: 0.0005   reward MA: 0.55   mean loss: 0   mean max Q: nan
# episode: 21   frame: 2874   score: 0.0   memory length: 2769   epsilon: 1.0   steps: 120   lr: 0.0005   reward MA: 0.524   mean loss: 0   mean max Q: nan
# episode: 22   frame: 3022   score: 1.0   memory length: 2912   epsilon: 1.0   steps: 148   lr: 0.0005   reward MA: 0.545   mean loss: 0   mean max Q: nan
# episode: 23   frame: 3205   score: 2.0   memory length: 3090   epsilon: 1.0   steps: 183   lr: 0.0005   reward MA: 0.609   mean loss: 0   mean max Q: nan
# episode: 24   frame: 3325   score: 0.0   memory length: 3205   epsilon: 1.0   steps: 120   lr: 0.0005   reward MA: 0.583   mean loss: 0   mean max Q: nan
# episode: 25   frame: 3445   score: 0.0   memory length: 3320   epsilon: 1.0   steps: 120   lr: 0.0005   reward MA: 0.56   mean loss: 0   mean max Q: nan
# episode: 26   frame: 3613   score: 1.0   memory length: 3483   epsilon: 1.0   steps: 168   lr: 0.0005   reward MA: 0.577   mean loss: 0   mean max Q: nan
# episode: 27   frame: 3761   score: 1.0   memory length: 3626   epsilon: 1.0   steps: 148   lr: 0.0005   reward MA: 0.593   mean loss: 0   mean max Q: nan
# episode: 28   frame: 3881   score: 0.0   memory length: 3741   epsilon: 1.0   steps: 120   lr: 0.0005   reward MA: 0.571   mean loss: 0   mean max Q: nan
# episode: 29   frame: 4107   score: 3.0   memory length: 3962   epsilon: 1.0   steps: 226   lr: 0.0005   reward MA: 0.655   mean loss: 0   mean max Q: nan
# episode: 30   frame: 4273   score: 1.0   memory length: 4123   epsilon: 1.0   steps: 166   lr: 0.0005   reward MA: 0.667   mean loss: 0   mean max Q: nan
# episode: 31   frame: 4421   score: 1.0   memory length: 4266   epsilon: 1.0   steps: 148   lr: 0.0005   reward MA: 0.677   mean loss: 0   mean max Q: nan
# episode: 32   frame: 4541   score: 0.0   memory length: 4381   epsilon: 1.0   steps: 120   lr: 0.0005   reward MA: 0.656   mean loss: 0   mean max Q: nan
# episode: 33   frame: 4707   score: 1.0   memory length: 4542   epsilon: 1.0   steps: 166   lr: 0.0005   reward MA: 0.667   mean loss: 0   mean max Q: nan
# episode: 34   frame: 4827   score: 0.0   memory length: 4657   epsilon: 1.0   steps: 120   lr: 0.0005   reward MA: 0.647   mean loss: 0   mean max Q: nan
# episode: 35   frame: 4975   score: 1.0   memory length: 4800   epsilon: 1.0   steps: 148   lr: 0.0005   reward MA: 0.657   mean loss: 0   mean max Q: nan
# episode: 36   frame: 5225   score: 3.0   memory length: 5045   epsilon: 1.0   steps: 250   lr: 0.0005   reward MA: 0.722   mean loss: 0   mean max Q: nan
# episode: 37   frame: 5373   score: 1.0   memory length: 5188   epsilon: 1.0   steps: 148   lr: 0.0005   reward MA: 0.73   mean loss: 0   mean max Q: nan
# episode: 38   frame: 5493   score: 0.0   memory length: 5303   epsilon: 1.0   steps: 120   lr: 0.0005   reward MA: 0.711   mean loss: 0   mean max Q: nan
# episode: 39   frame: 5641   score: 1.0   memory length: 5446   epsilon: 1.0   steps: 148   lr: 0.0005   reward MA: 0.718   mean loss: 0   mean max Q: nan
# episode: 40   frame: 5761   score: 0.0   memory length: 5561   epsilon: 1.0   steps: 120   lr: 0.0005   reward MA: 0.7   mean loss: 0   mean max Q: nan
# episode: 41   frame: 5881   score: 0.0   memory length: 5676   epsilon: 1.0   steps: 120   lr: 0.0005   reward MA: 0.683   mean loss: 0   mean max Q: nan
# episode: 42   frame: 6029   score: 1.0   memory length: 5819   epsilon: 1.0   steps: 148   lr: 0.0005   reward MA: 0.69   mean loss: 0   mean max Q: nan
# episode: 43   frame: 6149   score: 0.0   memory length: 5934   epsilon: 1.0   steps: 120   lr: 0.0005   reward MA: 0.674   mean loss: 0   mean max Q: nan
# episode: 44   frame: 6269   score: 0.0   memory length: 6049   epsilon: 1.0   steps: 120   lr: 0.0005   reward MA: 0.659   mean loss: 0   mean max Q: nan
# episode: 45   frame: 6417   score: 1.0   memory length: 6192   epsilon: 1.0   steps: 148   lr: 0.0005   reward MA: 0.667   mean loss: 0   mean max Q: nan
# episode: 46   frame: 6585   score: 1.0   memory length: 6355   epsilon: 1.0   steps: 168   lr: 0.0005   reward MA: 0.674   mean loss: 0   mean max Q: nan
# episode: 47   frame: 6884   score: 5.0   memory length: 6649   epsilon: 1.0   steps: 299   lr: 0.0005   reward MA: 0.766   mean loss: 0   mean max Q: nan
# episode: 48   frame: 7004   score: 0.0   memory length: 6764   epsilon: 1.0   steps: 120   lr: 0.0005   reward MA: 0.75   mean loss: 0   mean max Q: nan
# episode: 49   frame: 7183   score: 2.0   memory length: 6938   epsilon: 1.0   steps: 179   lr: 0.0005   reward MA: 0.776   mean loss: 0   mean max Q: nan
# episode: 50   frame: 7361   score: 2.0   memory length: 7111   epsilon: 1.0   steps: 178   lr: 0.0005   reward MA: 0.8   mean loss: 0   mean max Q: nan
# episode: 51   frame: 7509   score: 1.0   memory length: 7254   epsilon: 1.0   steps: 148   lr: 0.0005   reward MA: 0.82   mean loss: 0   mean max Q: nan
# episode: 52   frame: 7657   score: 1.0   memory length: 7397   epsilon: 1.0   steps: 148   lr: 0.0005   reward MA: 0.84   mean loss: 0   mean max Q: nan
# episode: 53   frame: 7777   score: 0.0   memory length: 7512   epsilon: 1.0   steps: 120   lr: 0.0005   reward MA: 0.84   mean loss: 0   mean max Q: nan
# episode: 54   frame: 7897   score: 0.0   memory length: 7627   epsilon: 1.0   steps: 120   lr: 0.0005   reward MA: 0.84   mean loss: 0   mean max Q: nan
# episode: 55   frame: 8075   score: 2.0   memory length: 7800   epsilon: 1.0   steps: 178   lr: 0.0005   reward MA: 0.88   mean loss: 0   mean max Q: nan
# episode: 56   frame: 8223   score: 1.0   memory length: 7943   epsilon: 1.0   steps: 148   lr: 0.0005   reward MA: 0.9   mean loss: 0   mean max Q: nan
# episode: 57   frame: 8371   score: 1.0   memory length: 8086   epsilon: 1.0   steps: 148   lr: 0.0005   reward MA: 0.92   mean loss: 0   mean max Q: nan
# episode: 58   frame: 8519   score: 1.0   memory length: 8229   epsilon: 1.0   steps: 148   lr: 0.0005   reward MA: 0.94   mean loss: 0   mean max Q: nan
# episode: 59   frame: 8639   score: 0.0   memory length: 8344   epsilon: 1.0   steps: 120   lr: 0.0005   reward MA: 0.9   mean loss: 0   mean max Q: nan
# episode: 60   frame: 8816   score: 2.0   memory length: 8516   epsilon: 1.0   steps: 177   lr: 0.0005   reward MA: 0.86   mean loss: 0   mean max Q: nan
# episode: 61   frame: 8984   score: 1.0   memory length: 8679   epsilon: 1.0   steps: 168   lr: 0.0005   reward MA: 0.88   mean loss: 0   mean max Q: nan
# episode: 62   frame: 9132   score: 1.0   memory length: 8822   epsilon: 1.0   steps: 148   lr: 0.0005   reward MA: 0.9   mean loss: 0   mean max Q: nan
# episode: 63   frame: 9280   score: 1.0   memory length: 8965   epsilon: 1.0   steps: 148   lr: 0.0005   reward MA: 0.88   mean loss: 0   mean max Q: nan
# episode: 64   frame: 9400   score: 0.0   memory length: 9080   epsilon: 1.0   steps: 120   lr: 0.0005   reward MA: 0.88   mean loss: 0   mean max Q: nan
# episode: 65   frame: 9607   score: 3.0   memory length: 9282   epsilon: 1.0   steps: 207   lr: 0.0005   reward MA: 0.92   mean loss: 0   mean max Q: nan
# episode: 66   frame: 9833   score: 3.0   memory length: 9503   epsilon: 1.0   steps: 226   lr: 0.0005   reward MA: 0.98   mean loss: 0   mean max Q: nan
# episode: 67   frame: 9981   score: 1.0   memory length: 9646   epsilon: 1.0   steps: 148   lr: 0.0005   reward MA: 0.98   mean loss: 0   mean max Q: nan
# episode: 68   frame: 10175   score: 2.0   memory length: 9835   epsilon: 1.0   steps: 194   lr: 0.0005   reward MA: 1.0   mean loss: 0   mean max Q: nan
# episode: 69   frame: 10371   score: 2.0   memory length: 10026   epsilon: 1.0   steps: 196   lr: 0.0005   reward MA: 1.04   mean loss: 0   mean max Q: nan
# episode: 70   frame: 10491   score: 0.0   memory length: 10141   epsilon: 1.0   steps: 120   lr: 0.0005   reward MA: 1.04   mean loss: 0   mean max Q: nan
# episode: 71   frame: 10639   score: 1.0   memory length: 10284   epsilon: 1.0   steps: 148   lr: 0.0005   reward MA: 1.06   mean loss: 0   mean max Q: nan
# episode: 72   frame: 10759   score: 0.0   memory length: 10399   epsilon: 1.0   steps: 120   lr: 0.0005   reward MA: 1.04   mean loss: 0   mean max Q: nan
# episode: 73   frame: 10879   score: 0.0   memory length: 10514   epsilon: 1.0   steps: 120   lr: 0.0005   reward MA: 1.0   mean loss: 0   mean max Q: nan
# episode: 74   frame: 10999   score: 0.0   memory length: 10629   epsilon: 1.0   steps: 120   lr: 0.0005   reward MA: 1.0   mean loss: 0   mean max Q: nan
# episode: 75   frame: 11177   score: 2.0   memory length: 10802   epsilon: 1.0   steps: 178   lr: 0.0005   reward MA: 1.04   mean loss: 0   mean max Q: nan
# episode: 76   frame: 11442   score: 3.0   memory length: 11062   epsilon: 1.0   steps: 265   lr: 0.0005   reward MA: 1.08   mean loss: 0   mean max Q: nan
# episode: 77   frame: 11562   score: 0.0   memory length: 11177   epsilon: 1.0   steps: 120   lr: 0.0005   reward MA: 1.06   mean loss: 0   mean max Q: nan
# episode: 78   frame: 11682   score: 0.0   memory length: 11292   epsilon: 1.0   steps: 120   lr: 0.0005   reward MA: 1.06   mean loss: 0   mean max Q: nan
# episode: 79   frame: 11850   score: 1.0   memory length: 11455   epsilon: 1.0   steps: 168   lr: 0.0005   reward MA: 1.02   mean loss: 0   mean max Q: nan
# episode: 80   frame: 11998   score: 1.0   memory length: 11598   epsilon: 1.0   steps: 148   lr: 0.0005   reward MA: 1.02   mean loss: 0   mean max Q: nan
# episode: 81   frame: 12118   score: 0.0   memory length: 11713   epsilon: 1.0   steps: 120   lr: 0.0005   reward MA: 1.0   mean loss: 0   mean max Q: nan
# episode: 82   frame: 12238   score: 0.0   memory length: 11828   epsilon: 1.0   steps: 120   lr: 0.0005   reward MA: 1.0   mean loss: 0   mean max Q: nan
# episode: 83   frame: 12358   score: 0.0   memory length: 11943   epsilon: 1.0   steps: 120   lr: 0.0005   reward MA: 0.98   mean loss: 0   mean max Q: nan
# episode: 84   frame: 12604   score: 3.0   memory length: 12184   epsilon: 1.0   steps: 246   lr: 0.0005   reward MA: 1.04   mean loss: 0   mean max Q: nan
# episode: 85   frame: 12752   score: 1.0   memory length: 12327   epsilon: 1.0   steps: 148   lr: 0.0005   reward MA: 1.04   mean loss: 0   mean max Q: nan
# episode: 86   frame: 12872   score: 0.0   memory length: 12442   epsilon: 1.0   steps: 120   lr: 0.0005   reward MA: 0.98   mean loss: 0   mean max Q: nan
# episode: 87   frame: 12992   score: 0.0   memory length: 12557   epsilon: 1.0   steps: 120   lr: 0.0005   reward MA: 0.96   mean loss: 0   mean max Q: nan
# episode: 88   frame: 13234   score: 3.0   memory length: 12794   epsilon: 1.0   steps: 242   lr: 0.0005   reward MA: 1.02   mean loss: 0   mean max Q: nan
# episode: 89   frame: 13413   score: 2.0   memory length: 12968   epsilon: 1.0   steps: 179   lr: 0.0005   reward MA: 1.04   mean loss: 0   mean max Q: nan
# episode: 90   frame: 13533   score: 0.0   memory length: 13083   epsilon: 1.0   steps: 120   lr: 0.0005   reward MA: 1.04   mean loss: 0   mean max Q: nan
# episode: 91   frame: 13744   score: 3.0   memory length: 13289   epsilon: 1.0   steps: 211   lr: 0.0005   reward MA: 1.1   mean loss: 0   mean max Q: nan
# episode: 92   frame: 13910   score: 1.0   memory length: 13450   epsilon: 1.0   steps: 166   lr: 0.0005   reward MA: 1.1   mean loss: 0   mean max Q: nan
# episode: 93   frame: 14058   score: 1.0   memory length: 13593   epsilon: 1.0   steps: 148   lr: 0.0005   reward MA: 1.12   mean loss: 0   mean max Q: nan
# episode: 94   frame: 14178   score: 0.0   memory length: 13708   epsilon: 1.0   steps: 120   lr: 0.0005   reward MA: 1.12   mean loss: 0   mean max Q: nan
# episode: 95   frame: 14298   score: 0.0   memory length: 13823   epsilon: 1.0   steps: 120   lr: 0.0005   reward MA: 1.1   mean loss: 0   mean max Q: nan
# episode: 96   frame: 14418   score: 0.0   memory length: 13938   epsilon: 1.0   steps: 120   lr: 0.0005   reward MA: 1.08   mean loss: 0   mean max Q: nan
# episode: 97   frame: 14538   score: 0.0   memory length: 14053   epsilon: 1.0   steps: 120   lr: 0.0005   reward MA: 0.98   mean loss: 0   mean max Q: nan
# episode: 98   frame: 14734   score: 2.0   memory length: 14244   epsilon: 1.0   steps: 196   lr: 0.0005   reward MA: 1.02   mean loss: 0   mean max Q: nan
# episode: 99   frame: 14854   score: 0.0   memory length: 14359   epsilon: 1.0   steps: 120   lr: 0.0005   reward MA: 0.98   mean loss: 0   mean max Q: nan
# episode: 100   frame: 14974   score: 0.0   memory length: 14474   epsilon: 1.0   steps: 120   lr: 0.0005   reward MA: 0.94   mean loss: 0   mean max Q: nan
# episode: 101   frame: 15094   score: 0.0   memory length: 14589   epsilon: 1.0   steps: 120   lr: 0.0005   reward MA: 0.92   mean loss: 0   mean max Q: nan
# episode: 102   frame: 15324   score: 3.0   memory length: 14814   epsilon: 1.0   steps: 230   lr: 0.0005   reward MA: 0.96   mean loss: 0   mean max Q: nan
# episode: 103   frame: 15444   score: 0.0   memory length: 14929   epsilon: 1.0   steps: 120   lr: 0.0005   reward MA: 0.96   mean loss: 0   mean max Q: nan
# episode: 104   frame: 15564   score: 0.0   memory length: 15044   epsilon: 1.0   steps: 120   lr: 0.0005   reward MA: 0.96   mean loss: 0   mean max Q: nan
# episode: 105   frame: 15684   score: 0.0   memory length: 15159   epsilon: 1.0   steps: 120   lr: 0.0005   reward MA: 0.92   mean loss: 0   mean max Q: nan
# episode: 106   frame: 15832   score: 1.0   memory length: 15302   epsilon: 1.0   steps: 148   lr: 0.0005   reward MA: 0.92   mean loss: 0   mean max Q: nan
# episode: 107   frame: 15952   score: 0.0   memory length: 15417   epsilon: 1.0   steps: 120   lr: 0.0005   reward MA: 0.9   mean loss: 0   mean max Q: nan
# episode: 108   frame: 16072   score: 0.0   memory length: 15532   epsilon: 1.0   steps: 120   lr: 0.0005   reward MA: 0.88   mean loss: 0   mean max Q: nan
# episode: 109   frame: 16220   score: 1.0   memory length: 15675   epsilon: 1.0   steps: 148   lr: 0.0005   reward MA: 0.9   mean loss: 0   mean max Q: nan
# episode: 110   frame: 16386   score: 1.0   memory length: 15836   epsilon: 1.0   steps: 166   lr: 0.0005   reward MA: 0.88   mean loss: 0   mean max Q: nan
# episode: 111   frame: 16582   score: 2.0   memory length: 16027   epsilon: 1.0   steps: 196   lr: 0.0005   reward MA: 0.9   mean loss: 0   mean max Q: nan
# episode: 112   frame: 16730   score: 1.0   memory length: 16170   epsilon: 1.0   steps: 148   lr: 0.0005   reward MA: 0.9   mean loss: 0   mean max Q: nan
# episode: 113   frame: 16850   score: 0.0   memory length: 16285   epsilon: 1.0   steps: 120   lr: 0.0005   reward MA: 0.88   mean loss: 0   mean max Q: nan
# episode: 114   frame: 16970   score: 0.0   memory length: 16400   epsilon: 1.0   steps: 120   lr: 0.0005   reward MA: 0.88   mean loss: 0   mean max Q: nan
# episode: 115   frame: 17090   score: 0.0   memory length: 16515   epsilon: 1.0   steps: 120   lr: 0.0005   reward MA: 0.82   mean loss: 0   mean max Q: nan
# episode: 116   frame: 17286   score: 2.0   memory length: 16706   epsilon: 1.0   steps: 196   lr: 0.0005   reward MA: 0.8   mean loss: 0   mean max Q: nan
# episode: 117   frame: 17406   score: 0.0   memory length: 16821   epsilon: 1.0   steps: 120   lr: 0.0005   reward MA: 0.78   mean loss: 0   mean max Q: nan
# episode: 118   frame: 17554   score: 1.0   memory length: 16964   epsilon: 1.0   steps: 148   lr: 0.0005   reward MA: 0.76   mean loss: 0   mean max Q: nan
# episode: 119   frame: 17750   score: 2.0   memory length: 17155   epsilon: 1.0   steps: 196   lr: 0.0005   reward MA: 0.76   mean loss: 0   mean max Q: nan
# episode: 120   frame: 17870   score: 0.0   memory length: 17270   epsilon: 1.0   steps: 120   lr: 0.0005   reward MA: 0.76   mean loss: 0   mean max Q: nan
# episode: 121   frame: 17990   score: 0.0   memory length: 17385   epsilon: 1.0   steps: 120   lr: 0.0005   reward MA: 0.74   mean loss: 0   mean max Q: nan
# episode: 122   frame: 18110   score: 0.0   memory length: 17500   epsilon: 1.0   steps: 120   lr: 0.0005   reward MA: 0.74   mean loss: 0   mean max Q: nan
# episode: 123   frame: 18307   score: 2.0   memory length: 17692   epsilon: 1.0   steps: 197   lr: 0.0005   reward MA: 0.78   mean loss: 0   mean max Q: nan
# episode: 124   frame: 18427   score: 0.0   memory length: 17807   epsilon: 1.0   steps: 120   lr: 0.0005   reward MA: 0.78   mean loss: 0   mean max Q: nan
# episode: 125   frame: 18642   score: 2.0   memory length: 18017   epsilon: 1.0   steps: 215   lr: 0.0005   reward MA: 0.78   mean loss: 0   mean max Q: nan
# episode: 126   frame: 18839   score: 2.0   memory length: 18209   epsilon: 1.0   steps: 197   lr: 0.0005   reward MA: 0.76   mean loss: 0   mean max Q: nan
# episode: 127   frame: 18987   score: 1.0   memory length: 18352   epsilon: 1.0   steps: 148   lr: 0.0005   reward MA: 0.78   mean loss: 0   mean max Q: nan
# episode: 128   frame: 19135   score: 1.0   memory length: 18495   epsilon: 1.0   steps: 148   lr: 0.0005   reward MA: 0.8   mean loss: 0   mean max Q: nan
# episode: 129   frame: 19343   score: 3.0   memory length: 18698   epsilon: 1.0   steps: 208   lr: 0.0005   reward MA: 0.84   mean loss: 0   mean max Q: nan
# episode: 130   frame: 19491   score: 1.0   memory length: 18841   epsilon: 1.0   steps: 148   lr: 0.0005   reward MA: 0.84   mean loss: 0   mean max Q: nan
# episode: 131   frame: 19639   score: 1.0   memory length: 18984   epsilon: 1.0   steps: 148   lr: 0.0005   reward MA: 0.86   mean loss: 0   mean max Q: nan
# episode: 132   frame: 19807   score: 1.0   memory length: 19147   epsilon: 1.0   steps: 168   lr: 0.0005   reward MA: 0.88   mean loss: 0   mean max Q: nan
# episode: 133   frame: 19985   score: 2.0   memory length: 19320   epsilon: 1.0   steps: 178   lr: 0.0005   reward MA: 0.92   mean loss: 0   mean max Q: nan
# episode: 134   frame: 20105   score: 0.0   memory length: 19435   epsilon: 1.0   steps: 120   lr: 0.0005   reward MA: 0.86   mean loss: 0   mean max Q: nan
# episode: 135   frame: 20253   score: 1.0   memory length: 19578   epsilon: 1.0   steps: 148   lr: 0.0005   reward MA: 0.86   mean loss: 0   mean max Q: nan
# episode: 136   frame: 20373   score: 0.0   memory length: 19693   epsilon: 1.0   steps: 120   lr: 0.0005   reward MA: 0.86   mean loss: 0   mean max Q: nan
# episode: 137   frame: 20521   score: 1.0   memory length: 19836   epsilon: 1.0   steps: 148   lr: 0.0005   reward MA: 0.88   mean loss: 0   mean max Q: nan
# episode: 138   frame: 20721   score: 2.0   memory length: 20031   epsilon: 1.0   steps: 200   lr: 0.0005   reward MA: 0.86   mean loss: 0   mean max Q: nan
# episode: 139   frame: 20869   score: 1.0   memory length: 20174   epsilon: 1.0   steps: 148   lr: 0.0005   reward MA: 0.84   mean loss: 0   mean max Q: nan
# episode: 140   frame: 20989   score: 0.0   memory length: 20289   epsilon: 1.0   steps: 120   lr: 0.0005   reward MA: 0.84   mean loss: 0   mean max Q: nan
# episode: 141   frame: 21109   score: 0.0   memory length: 20404   epsilon: 1.0   steps: 120   lr: 0.0005   reward MA: 0.78   mean loss: 0   mean max Q: nan
# episode: 142   frame: 21287   score: 2.0   memory length: 20577   epsilon: 1.0   steps: 178   lr: 0.0005   reward MA: 0.8   mean loss: 0   mean max Q: nan
# episode: 143   frame: 21407   score: 0.0   memory length: 20692   epsilon: 1.0   steps: 120   lr: 0.0005   reward MA: 0.78   mean loss: 0   mean max Q: nan
# episode: 144   frame: 21555   score: 1.0   memory length: 20835   epsilon: 1.0   steps: 148   lr: 0.0005   reward MA: 0.8   mean loss: 0   mean max Q: nan
# episode: 145   frame: 21732   score: 2.0   memory length: 21007   epsilon: 1.0   steps: 177   lr: 0.0005   reward MA: 0.84   mean loss: 0   mean max Q: nan
# episode: 146   frame: 21880   score: 1.0   memory length: 21150   epsilon: 1.0   steps: 148   lr: 0.0005   reward MA: 0.86   mean loss: 0   mean max Q: nan
# episode: 147   frame: 22000   score: 0.0   memory length: 21265   epsilon: 1.0   steps: 120   lr: 0.0005   reward MA: 0.86   mean loss: 0   mean max Q: nan
# episode: 148   frame: 22120   score: 0.0   memory length: 21380   epsilon: 1.0   steps: 120   lr: 0.0005   reward MA: 0.82   mean loss: 0   mean max Q: nan
# episode: 149   frame: 22240   score: 0.0   memory length: 21495   epsilon: 1.0   steps: 120   lr: 0.0005   reward MA: 0.82   mean loss: 0   mean max Q: nan
# episode: 150   frame: 22409   score: 1.0   memory length: 21659   epsilon: 1.0   steps: 169   lr: 0.0005   reward MA: 0.84   mean loss: 0   mean max Q: nan
# episode: 151   frame: 22587   score: 2.0   memory length: 21832   epsilon: 1.0   steps: 178   lr: 0.0005   reward MA: 0.88   mean loss: 0   mean max Q: nan
# episode: 152   frame: 22707   score: 0.0   memory length: 21947   epsilon: 1.0   steps: 120   lr: 0.0005   reward MA: 0.82   mean loss: 0   mean max Q: nan
# episode: 153   frame: 22875   score: 1.0   memory length: 22110   epsilon: 1.0   steps: 168   lr: 0.0005   reward MA: 0.84   mean loss: 0   mean max Q: nan
# episode: 154   frame: 22995   score: 0.0   memory length: 22225   epsilon: 1.0   steps: 120   lr: 0.0005   reward MA: 0.84   mean loss: 0   mean max Q: nan
# episode: 155   frame: 23115   score: 0.0   memory length: 22340   epsilon: 1.0   steps: 120   lr: 0.0005   reward MA: 0.84   mean loss: 0   mean max Q: nan
# episode: 156   frame: 23312   score: 2.0   memory length: 22532   epsilon: 1.0   steps: 197   lr: 0.0005   reward MA: 0.86   mean loss: 0   mean max Q: nan
# episode: 157   frame: 23526   score: 2.0   memory length: 22741   epsilon: 1.0   steps: 214   lr: 0.0005   reward MA: 0.9   mean loss: 0   mean max Q: nan
# episode: 158   frame: 23674   score: 1.0   memory length: 22884   epsilon: 1.0   steps: 148   lr: 0.0005   reward MA: 0.92   mean loss: 0   mean max Q: nan
# episode: 159   frame: 23822   score: 1.0   memory length: 23027   epsilon: 1.0   steps: 148   lr: 0.0005   reward MA: 0.92   mean loss: 0   mean max Q: nan
# episode: 160   frame: 23970   score: 1.0   memory length: 23170   epsilon: 1.0   steps: 148   lr: 0.0005   reward MA: 0.92   mean loss: 0   mean max Q: nan
# episode: 161   frame: 24147   score: 2.0   memory length: 23342   epsilon: 1.0   steps: 177   lr: 0.0005   reward MA: 0.92   mean loss: 0   mean max Q: nan
# episode: 162   frame: 24267   score: 0.0   memory length: 23457   epsilon: 1.0   steps: 120   lr: 0.0005   reward MA: 0.9   mean loss: 0   mean max Q: nan
# episode: 163   frame: 24387   score: 0.0   memory length: 23572   epsilon: 1.0   steps: 120   lr: 0.0005   reward MA: 0.9   mean loss: 0   mean max Q: nan
# episode: 164   frame: 24507   score: 0.0   memory length: 23687   epsilon: 1.0   steps: 120   lr: 0.0005   reward MA: 0.9   mean loss: 0   mean max Q: nan
# episode: 165   frame: 24627   score: 0.0   memory length: 23802   epsilon: 1.0   steps: 120   lr: 0.0005   reward MA: 0.9   mean loss: 0   mean max Q: nan
# episode: 166   frame: 24747   score: 0.0   memory length: 23917   epsilon: 1.0   steps: 120   lr: 0.0005   reward MA: 0.86   mean loss: 0   mean max Q: nan
# episode: 167   frame: 24895   score: 1.0   memory length: 24060   epsilon: 1.0   steps: 148   lr: 0.0005   reward MA: 0.88   mean loss: 0   mean max Q: nan
# episode: 168   frame: 25073   score: 2.0   memory length: 24233   epsilon: 1.0   steps: 178   lr: 0.0005   reward MA: 0.9   mean loss: 0   mean max Q: nan
# episode: 169   frame: 25193   score: 0.0   memory length: 24348   epsilon: 1.0   steps: 120   lr: 0.0005   reward MA: 0.86   mean loss: 0   mean max Q: nan
# episode: 170   frame: 25359   score: 1.0   memory length: 24509   epsilon: 1.0   steps: 166   lr: 0.0005   reward MA: 0.88   mean loss: 0   mean max Q: nan
# episode: 171   frame: 25536   score: 2.0   memory length: 24681   epsilon: 1.0   steps: 177   lr: 0.0005   reward MA: 0.92   mean loss: 0   mean max Q: nan
# episode: 172   frame: 25656   score: 0.0   memory length: 24796   epsilon: 1.0   steps: 120   lr: 0.0005   reward MA: 0.92   mean loss: 0   mean max Q: nan
# episode: 173   frame: 25856   score: 2.0   memory length: 24991   epsilon: 1.0   steps: 200   lr: 0.0005   reward MA: 0.92   mean loss: 0   mean max Q: nan
# episode: 174   frame: 25976   score: 0.0   memory length: 25106   epsilon: 1.0   steps: 120   lr: 0.0005   reward MA: 0.92   mean loss: 0   mean max Q: nan
# episode: 175   frame: 26124   score: 1.0   memory length: 25249   epsilon: 1.0   steps: 148   lr: 0.0005   reward MA: 0.9   mean loss: 0   mean max Q: nan
# episode: 176   frame: 26318   score: 2.0   memory length: 25438   epsilon: 1.0   steps: 194   lr: 0.0005   reward MA: 0.9   mean loss: 0   mean max Q: nan
# episode: 177   frame: 26532   score: 2.0   memory length: 25647   epsilon: 1.0   steps: 214   lr: 0.0005   reward MA: 0.92   mean loss: 0   mean max Q: nan
# episode: 178   frame: 26739   score: 3.0   memory length: 25849   epsilon: 1.0   steps: 207   lr: 0.0005   reward MA: 0.96   mean loss: 0   mean max Q: nan
# episode: 179   frame: 26859   score: 0.0   memory length: 25964   epsilon: 1.0   steps: 120   lr: 0.0005   reward MA: 0.9   mean loss: 0   mean max Q: nan
# episode: 180   frame: 27073   score: 2.0   memory length: 26173   epsilon: 1.0   steps: 214   lr: 0.0005   reward MA: 0.92   mean loss: 0   mean max Q: nan
# episode: 181   frame: 27221   score: 1.0   memory length: 26316   epsilon: 1.0   steps: 148   lr: 0.0005   reward MA: 0.92   mean loss: 0   mean max Q: nan
# episode: 182   frame: 27369   score: 1.0   memory length: 26459   epsilon: 1.0   steps: 148   lr: 0.0005   reward MA: 0.92   mean loss: 0   mean max Q: nan
# episode: 183   frame: 27489   score: 0.0   memory length: 26574   epsilon: 1.0   steps: 120   lr: 0.0005   reward MA: 0.88   mean loss: 0   mean max Q: nan
# episode: 184   frame: 27666   score: 2.0   memory length: 26746   epsilon: 1.0   steps: 177   lr: 0.0005   reward MA: 0.92   mean loss: 0   mean max Q: nan
# episode: 185   frame: 27786   score: 0.0   memory length: 26861   epsilon: 1.0   steps: 120   lr: 0.0005   reward MA: 0.9   mean loss: 0   mean max Q: nan
# episode: 186   frame: 27954   score: 1.0   memory length: 27024   epsilon: 1.0   steps: 168   lr: 0.0005   reward MA: 0.92   mean loss: 0   mean max Q: nan
# episode: 187   frame: 28102   score: 1.0   memory length: 27167   epsilon: 1.0   steps: 148   lr: 0.0005   reward MA: 0.92   mean loss: 0   mean max Q: nan
# episode: 188   frame: 28299   score: 2.0   memory length: 27359   epsilon: 1.0   steps: 197   lr: 0.0005   reward MA: 0.92   mean loss: 0   mean max Q: nan
# episode: 189   frame: 28518   score: 2.0   memory length: 27573   epsilon: 1.0   steps: 219   lr: 0.0005   reward MA: 0.94   mean loss: 0   mean max Q: nan
# episode: 190   frame: 28666   score: 1.0   memory length: 27716   epsilon: 1.0   steps: 148   lr: 0.0005   reward MA: 0.96   mean loss: 0   mean max Q: nan
# episode: 191   frame: 28814   score: 1.0   memory length: 27859   epsilon: 1.0   steps: 148   lr: 0.0005   reward MA: 0.98   mean loss: 0   mean max Q: nan
# episode: 192   frame: 28962   score: 1.0   memory length: 28002   epsilon: 1.0   steps: 148   lr: 0.0005   reward MA: 0.96   mean loss: 0   mean max Q: nan
# episode: 193   frame: 29128   score: 1.0   memory length: 28163   epsilon: 1.0   steps: 166   lr: 0.0005   reward MA: 0.98   mean loss: 0   mean max Q: nan
# episode: 194   frame: 29248   score: 0.0   memory length: 28278   epsilon: 1.0   steps: 120   lr: 0.0005   reward MA: 0.96   mean loss: 0   mean max Q: nan
# episode: 195   frame: 29524   score: 4.0   memory length: 28549   epsilon: 1.0   steps: 276   lr: 0.0005   reward MA: 1.0   mean loss: 0   mean max Q: nan
# episode: 196   frame: 29672   score: 1.0   memory length: 28692   epsilon: 1.0   steps: 148   lr: 0.0005   reward MA: 1.0   mean loss: 0   mean max Q: nan
# episode: 197   frame: 29792   score: 0.0   memory length: 28807   epsilon: 1.0   steps: 120   lr: 0.0005   reward MA: 1.0   mean loss: 0   mean max Q: nan
# episode: 198   frame: 29912   score: 0.0   memory length: 28922   epsilon: 1.0   steps: 120   lr: 0.0005   reward MA: 1.0   mean loss: 0   mean max Q: nan
# episode: 199   frame: 30060   score: 1.0   memory length: 29065   epsilon: 1.0   steps: 148   lr: 0.0005   reward MA: 1.02   mean loss: 0   mean max Q: nan
# episode: 200   frame: 30228   score: 1.0   memory length: 29228   epsilon: 1.0   steps: 168   lr: 0.0005   reward MA: 1.02   mean loss: 0   mean max Q: nan
# episode: 201   frame: 30348   score: 0.0   memory length: 29343   epsilon: 1.0   steps: 120   lr: 0.0005   reward MA: 0.98   mean loss: 0   mean max Q: nan
# episode: 202   frame: 30496   score: 1.0   memory length: 29486   epsilon: 1.0   steps: 148   lr: 0.0005   reward MA: 1.0   mean loss: 0   mean max Q: nan
# episode: 203   frame: 30743   score: 3.0   memory length: 29728   epsilon: 1.0   steps: 247   lr: 0.0005   reward MA: 1.04   mean loss: 0   mean max Q: nan
# episode: 204   frame: 30891   score: 1.0   memory length: 29871   epsilon: 1.0   steps: 148   lr: 0.0005   reward MA: 1.06   mean loss: 0   mean max Q: nan
# episode: 205   frame: 31039   score: 1.0   memory length: 30014   epsilon: 1.0   steps: 148   lr: 0.0005   reward MA: 1.08   mean loss: 0   mean max Q: nan
# episode: 206   frame: 31159   score: 0.0   memory length: 30129   epsilon: 1.0   steps: 120   lr: 0.0005   reward MA: 1.04   mean loss: 0   mean max Q: nan
# episode: 207   frame: 31279   score: 0.0   memory length: 30244   epsilon: 1.0   steps: 120   lr: 0.0005   reward MA: 1.0   mean loss: 0   mean max Q: nan
# episode: 208   frame: 31427   score: 1.0   memory length: 30387   epsilon: 1.0   steps: 148   lr: 0.0005   reward MA: 1.0   mean loss: 0   mean max Q: nan
# episode: 209   frame: 31646   score: 2.0   memory length: 30601   epsilon: 1.0   steps: 219   lr: 0.0005   reward MA: 1.02   mean loss: 0   mean max Q: nan
# episode: 210   frame: 31824   score: 2.0   memory length: 30774   epsilon: 1.0   steps: 178   lr: 0.0005   reward MA: 1.04   mean loss: 0   mean max Q: nan
# episode: 211   frame: 31944   score: 0.0   memory length: 30889   epsilon: 1.0   steps: 120   lr: 0.0005   reward MA: 1.0   mean loss: 0   mean max Q: nan
# episode: 212   frame: 32092   score: 1.0   memory length: 31032   epsilon: 1.0   steps: 148   lr: 0.0005   reward MA: 1.02   mean loss: 0   mean max Q: nan
# episode: 213   frame: 32212   score: 0.0   memory length: 31147   epsilon: 1.0   steps: 120   lr: 0.0005   reward MA: 1.02   mean loss: 0   mean max Q: nan
# episode: 214   frame: 32360   score: 1.0   memory length: 31290   epsilon: 1.0   steps: 148   lr: 0.0005   reward MA: 1.04   mean loss: 0   mean max Q: nan
# episode: 215   frame: 32480   score: 0.0   memory length: 31405   epsilon: 1.0   steps: 120   lr: 0.0005   reward MA: 1.04   mean loss: 0   mean max Q: nan
# episode: 216   frame: 32600   score: 0.0   memory length: 31520   epsilon: 1.0   steps: 120   lr: 0.0005   reward MA: 1.04   mean loss: 0   mean max Q: nan
# episode: 217   frame: 32817   score: 2.0   memory length: 31732   epsilon: 1.0   steps: 217   lr: 0.0005   reward MA: 1.06   mean loss: 0   mean max Q: nan
# episode: 218   frame: 32965   score: 1.0   memory length: 31875   epsilon: 1.0   steps: 148   lr: 0.0005   reward MA: 1.04   mean loss: 0   mean max Q: nan
# episode: 219   frame: 33085   score: 0.0   memory length: 31990   epsilon: 1.0   steps: 120   lr: 0.0005   reward MA: 1.04   mean loss: 0   mean max Q: nan
# episode: 220   frame: 33205   score: 0.0   memory length: 32105   epsilon: 1.0   steps: 120   lr: 0.0005   reward MA: 1.02   mean loss: 0   mean max Q: nan
# episode: 221   frame: 33325   score: 0.0   memory length: 32220   epsilon: 1.0   steps: 120   lr: 0.0005   reward MA: 0.98   mean loss: 0   mean max Q: nan
# episode: 222   frame: 33473   score: 1.0   memory length: 32363   epsilon: 1.0   steps: 148   lr: 0.0005   reward MA: 1.0   mean loss: 0   mean max Q: nan
# episode: 223   frame: 33593   score: 0.0   memory length: 32478   epsilon: 1.0   steps: 120   lr: 0.0005   reward MA: 0.96   mean loss: 0   mean max Q: nan
# episode: 224   frame: 33741   score: 1.0   memory length: 32621   epsilon: 1.0   steps: 148   lr: 0.0005   reward MA: 0.98   mean loss: 0   mean max Q: nan
# episode: 225   frame: 33861   score: 0.0   memory length: 32736   epsilon: 1.0   steps: 120   lr: 0.0005   reward MA: 0.96   mean loss: 0   mean max Q: nan
# episode: 226   frame: 34009   score: 1.0   memory length: 32879   epsilon: 1.0   steps: 148   lr: 0.0005   reward MA: 0.94   mean loss: 0   mean max Q: nan
# episode: 227   frame: 34129   score: 0.0   memory length: 32994   epsilon: 1.0   steps: 120   lr: 0.0005   reward MA: 0.9   mean loss: 0   mean max Q: nan
# episode: 228   frame: 34349   score: 2.0   memory length: 33209   epsilon: 1.0   steps: 220   lr: 0.0005   reward MA: 0.88   mean loss: 0   mean max Q: nan
# episode: 229   frame: 34469   score: 0.0   memory length: 33324   epsilon: 1.0   steps: 120   lr: 0.0005   reward MA: 0.88   mean loss: 0   mean max Q: nan
# episode: 230   frame: 34589   score: 0.0   memory length: 33439   epsilon: 1.0   steps: 120   lr: 0.0005   reward MA: 0.84   mean loss: 0   mean max Q: nan
# episode: 231   frame: 34709   score: 0.0   memory length: 33554   epsilon: 1.0   steps: 120   lr: 0.0005   reward MA: 0.82   mean loss: 0   mean max Q: nan
# episode: 232   frame: 34829   score: 0.0   memory length: 33669   epsilon: 1.0   steps: 120   lr: 0.0005   reward MA: 0.8   mean loss: 0   mean max Q: nan
# episode: 233   frame: 34949   score: 0.0   memory length: 33784   epsilon: 1.0   steps: 120   lr: 0.0005   reward MA: 0.8   mean loss: 0   mean max Q: nan
# episode: 234   frame: 35169   score: 2.0   memory length: 33999   epsilon: 1.0   steps: 220   lr: 0.0005   reward MA: 0.8   mean loss: 0   mean max Q: nan
# episode: 235   frame: 35335   score: 1.0   memory length: 34160   epsilon: 1.0   steps: 166   lr: 0.0005   reward MA: 0.82   mean loss: 0   mean max Q: nan
# episode: 236   frame: 35455   score: 0.0   memory length: 34275   epsilon: 1.0   steps: 120   lr: 0.0005   reward MA: 0.8   mean loss: 0   mean max Q: nan
# episode: 237   frame: 35575   score: 0.0   memory length: 34390   epsilon: 1.0   steps: 120   lr: 0.0005   reward MA: 0.78   mean loss: 0   mean max Q: nan
# episode: 238   frame: 35695   score: 0.0   memory length: 34505   epsilon: 1.0   steps: 120   lr: 0.0005   reward MA: 0.74   mean loss: 0   mean max Q: nan
# episode: 239   frame: 35891   score: 2.0   memory length: 34696   epsilon: 1.0   steps: 196   lr: 0.0005   reward MA: 0.74   mean loss: 0   mean max Q: nan
# episode: 240   frame: 36039   score: 1.0   memory length: 34839   epsilon: 1.0   steps: 148   lr: 0.0005   reward MA: 0.74   mean loss: 0   mean max Q: nan
# episode: 241   frame: 36238   score: 2.0   memory length: 35033   epsilon: 1.0   steps: 199   lr: 0.0005   reward MA: 0.76   mean loss: 0   mean max Q: nan
# episode: 242   frame: 36358   score: 0.0   memory length: 35148   epsilon: 1.0   steps: 120   lr: 0.0005   reward MA: 0.74   mean loss: 0   mean max Q: nan
# episode: 243   frame: 36526   score: 1.0   memory length: 35311   epsilon: 1.0   steps: 168   lr: 0.0005   reward MA: 0.74   mean loss: 0   mean max Q: nan
# episode: 244   frame: 36646   score: 0.0   memory length: 35426   epsilon: 1.0   steps: 120   lr: 0.0005   reward MA: 0.74   mean loss: 0   mean max Q: nan
# episode: 245   frame: 36794   score: 1.0   memory length: 35569   epsilon: 1.0   steps: 148   lr: 0.0005   reward MA: 0.68   mean loss: 0   mean max Q: nan
# episode: 246   frame: 36914   score: 0.0   memory length: 35684   epsilon: 1.0   steps: 120   lr: 0.0005   reward MA: 0.66   mean loss: 0   mean max Q: nan
# episode: 247   frame: 37034   score: 0.0   memory length: 35799   epsilon: 1.0   steps: 120   lr: 0.0005   reward MA: 0.66   mean loss: 0   mean max Q: nan
# episode: 248   frame: 37154   score: 0.0   memory length: 35914   epsilon: 1.0   steps: 120   lr: 0.0005   reward MA: 0.66   mean loss: 0   mean max Q: nan
# episode: 249   frame: 37419   score: 3.0   memory length: 36174   epsilon: 1.0   steps: 265   lr: 0.0005   reward MA: 0.7   mean loss: 0   mean max Q: nan
# episode: 250   frame: 37674   score: 4.0   memory length: 36424   epsilon: 1.0   steps: 255   lr: 0.0005   reward MA: 0.76   mean loss: 0   mean max Q: nan
# episode: 251   frame: 37794   score: 0.0   memory length: 36539   epsilon: 1.0   steps: 120   lr: 0.0005   reward MA: 0.76   mean loss: 0   mean max Q: nan
# episode: 252   frame: 37942   score: 1.0   memory length: 36682   epsilon: 1.0   steps: 148   lr: 0.0005   reward MA: 0.76   mean loss: 0   mean max Q: nan
# episode: 253   frame: 38062   score: 0.0   memory length: 36797   epsilon: 1.0   steps: 120   lr: 0.0005   reward MA: 0.7   mean loss: 0   mean max Q: nan
# episode: 254   frame: 38277   score: 2.0   memory length: 37007   epsilon: 1.0   steps: 215   lr: 0.0005   reward MA: 0.72   mean loss: 0   mean max Q: nan
# episode: 255   frame: 38425   score: 1.0   memory length: 37150   epsilon: 1.0   steps: 148   lr: 0.0005   reward MA: 0.72   mean loss: 0   mean max Q: nan
# episode: 256   frame: 38545   score: 0.0   memory length: 37265   epsilon: 1.0   steps: 120   lr: 0.0005   reward MA: 0.72   mean loss: 0   mean max Q: nan
# episode: 257   frame: 38665   score: 0.0   memory length: 37380   epsilon: 1.0   steps: 120   lr: 0.0005   reward MA: 0.72   mean loss: 0   mean max Q: nan
# episode: 258   frame: 38843   score: 2.0   memory length: 37553   epsilon: 1.0   steps: 178   lr: 0.0005   reward MA: 0.74   mean loss: 0   mean max Q: nan
# episode: 259   frame: 38963   score: 0.0   memory length: 37668   epsilon: 1.0   steps: 120   lr: 0.0005   reward MA: 0.7   mean loss: 0   mean max Q: nan
# episode: 260   frame: 39182   score: 2.0   memory length: 37882   epsilon: 1.0   steps: 219   lr: 0.0005   reward MA: 0.7   mean loss: 0   mean max Q: nan
# episode: 261   frame: 39302   score: 0.0   memory length: 37997   epsilon: 1.0   steps: 120   lr: 0.0005   reward MA: 0.7   mean loss: 0   mean max Q: nan
# episode: 262   frame: 39450   score: 1.0   memory length: 38140   epsilon: 1.0   steps: 148   lr: 0.0005   reward MA: 0.7   mean loss: 0   mean max Q: nan
# episode: 263   frame: 39598   score: 1.0   memory length: 38283   epsilon: 1.0   steps: 148   lr: 0.0005   reward MA: 0.72   mean loss: 0   mean max Q: nan
# episode: 264   frame: 39718   score: 0.0   memory length: 38398   epsilon: 1.0   steps: 120   lr: 0.0005   reward MA: 0.7   mean loss: 0   mean max Q: nan
# episode: 265   frame: 39886   score: 1.0   memory length: 38561   epsilon: 1.0   steps: 168   lr: 0.0005   reward MA: 0.72   mean loss: 0   mean max Q: nan
# episode: 266   frame: 40133   score: 3.0   memory length: 38803   epsilon: 1.0   steps: 247   lr: 0.0005   reward MA: 0.78   mean loss: 0   mean max Q: nan
# episode: 267   frame: 40253   score: 0.0   memory length: 38918   epsilon: 1.0   steps: 120   lr: 0.0005   reward MA: 0.74   mean loss: 0   mean max Q: nan
# episode: 268   frame: 40401   score: 1.0   memory length: 39061   epsilon: 1.0   steps: 148   lr: 0.0005   reward MA: 0.74   mean loss: 0   mean max Q: nan
# episode: 269   frame: 40569   score: 1.0   memory length: 39224   epsilon: 1.0   steps: 168   lr: 0.0005   reward MA: 0.76   mean loss: 0   mean max Q: nan
# episode: 270   frame: 40689   score: 0.0   memory length: 39339   epsilon: 1.0   steps: 120   lr: 0.0005   reward MA: 0.76   mean loss: 0   mean max Q: nan
# episode: 271   frame: 40855   score: 1.0   memory length: 39500   epsilon: 1.0   steps: 166   lr: 0.0005   reward MA: 0.78   mean loss: 0   mean max Q: nan
# episode: 272   frame: 41062   score: 3.0   memory length: 39702   epsilon: 1.0   steps: 207   lr: 0.0005   reward MA: 0.82   mean loss: 0   mean max Q: nan
# episode: 273   frame: 41258   score: 2.0   memory length: 39893   epsilon: 1.0   steps: 196   lr: 0.0005   reward MA: 0.86   mean loss: 0   mean max Q: nan
# episode: 274   frame: 41378   score: 0.0   memory length: 40008   epsilon: 1.0   steps: 120   lr: 0.0005   reward MA: 0.84   mean loss: 0   mean max Q: nan
# episode: 275   frame: 41526   score: 1.0   memory length: 40151   epsilon: 1.0   steps: 148   lr: 0.0005   reward MA: 0.86   mean loss: 0   mean max Q: nan
# episode: 276   frame: 41646   score: 0.0   memory length: 40266   epsilon: 1.0   steps: 120   lr: 0.0005   reward MA: 0.84   mean loss: 0   mean max Q: nan
# episode: 277   frame: 41766   score: 0.0   memory length: 40381   epsilon: 1.0   steps: 120   lr: 0.0005   reward MA: 0.84   mean loss: 0   mean max Q: nan
# episode: 278   frame: 41914   score: 1.0   memory length: 40524   epsilon: 1.0   steps: 148   lr: 0.0005   reward MA: 0.82   mean loss: 0   mean max Q: nan
# episode: 279   frame: 42034   score: 0.0   memory length: 40639   epsilon: 1.0   steps: 120   lr: 0.0005   reward MA: 0.82   mean loss: 0   mean max Q: nan
# episode: 280   frame: 42154   score: 0.0   memory length: 40754   epsilon: 1.0   steps: 120   lr: 0.0005   reward MA: 0.82   mean loss: 0   mean max Q: nan
# episode: 281   frame: 42274   score: 0.0   memory length: 40869   epsilon: 1.0   steps: 120   lr: 0.0005   reward MA: 0.82   mean loss: 0   mean max Q: nan
# episode: 282   frame: 42394   score: 0.0   memory length: 40984   epsilon: 1.0   steps: 120   lr: 0.0005   reward MA: 0.82   mean loss: 0   mean max Q: nan
# episode: 283   frame: 42562   score: 1.0   memory length: 41147   epsilon: 1.0   steps: 168   lr: 0.0005   reward MA: 0.84   mean loss: 0   mean max Q: nan
# episode: 284   frame: 42682   score: 0.0   memory length: 41262   epsilon: 1.0   steps: 120   lr: 0.0005   reward MA: 0.8   mean loss: 0   mean max Q: nan
# episode: 285   frame: 42861   score: 2.0   memory length: 41436   epsilon: 1.0   steps: 179   lr: 0.0005   reward MA: 0.82   mean loss: 0   mean max Q: nan
# episode: 286   frame: 43029   score: 1.0   memory length: 41599   epsilon: 1.0   steps: 168   lr: 0.0005   reward MA: 0.84   mean loss: 0   mean max Q: nan
# episode: 287   frame: 43149   score: 0.0   memory length: 41714   epsilon: 1.0   steps: 120   lr: 0.0005   reward MA: 0.84   mean loss: 0   mean max Q: nan
# episode: 288   frame: 43269   score: 0.0   memory length: 41829   epsilon: 1.0   steps: 120   lr: 0.0005   reward MA: 0.84   mean loss: 0   mean max Q: nan
# episode: 289   frame: 43437   score: 1.0   memory length: 41992   epsilon: 1.0   steps: 168   lr: 0.0005   reward MA: 0.82   mean loss: 0   mean max Q: nan
# episode: 290   frame: 43557   score: 0.0   memory length: 42107   epsilon: 1.0   steps: 120   lr: 0.0005   reward MA: 0.8   mean loss: 0   mean max Q: nan
# episode: 291   frame: 43677   score: 0.0   memory length: 42222   epsilon: 1.0   steps: 120   lr: 0.0005   reward MA: 0.76   mean loss: 0   mean max Q: nan
# episode: 292   frame: 43797   score: 0.0   memory length: 42337   epsilon: 1.0   steps: 120   lr: 0.0005   reward MA: 0.76   mean loss: 0   mean max Q: nan
# episode: 293   frame: 43917   score: 0.0   memory length: 42452   epsilon: 1.0   steps: 120   lr: 0.0005   reward MA: 0.74   mean loss: 0   mean max Q: nan
# episode: 294   frame: 44172   score: 4.0   memory length: 42702   epsilon: 1.0   steps: 255   lr: 0.0005   reward MA: 0.82   mean loss: 0   mean max Q: nan
# episode: 295   frame: 44292   score: 0.0   memory length: 42817   epsilon: 1.0   steps: 120   lr: 0.0005   reward MA: 0.8   mean loss: 0   mean max Q: nan
# episode: 296   frame: 44489   score: 2.0   memory length: 43009   epsilon: 1.0   steps: 197   lr: 0.0005   reward MA: 0.84   mean loss: 0   mean max Q: nan
# episode: 297   frame: 44658   score: 1.0   memory length: 43173   epsilon: 1.0   steps: 169   lr: 0.0005   reward MA: 0.86   mean loss: 0   mean max Q: nan
# episode: 298   frame: 44778   score: 0.0   memory length: 43288   epsilon: 1.0   steps: 120   lr: 0.0005   reward MA: 0.86   mean loss: 0   mean max Q: nan
# episode: 299   frame: 44956   score: 2.0   memory length: 43461   epsilon: 1.0   steps: 178   lr: 0.0005   reward MA: 0.84   mean loss: 0   mean max Q: nan
# episode: 300   frame: 45104   score: 1.0   memory length: 43604   epsilon: 1.0   steps: 148   lr: 0.0005   reward MA: 0.78   mean loss: 0   mean max Q: nan
# episode: 301   frame: 45224   score: 0.0   memory length: 43719   epsilon: 1.0   steps: 120   lr: 0.0005   reward MA: 0.78   mean loss: 0   mean max Q: nan
# episode: 302   frame: 45402   score: 2.0   memory length: 43892   epsilon: 1.0   steps: 178   lr: 0.0005   reward MA: 0.8   mean loss: 0   mean max Q: nan
# episode: 303   frame: 45522   score: 0.0   memory length: 44007   epsilon: 1.0   steps: 120   lr: 0.0005   reward MA: 0.8   mean loss: 0   mean max Q: nan
# episode: 304   frame: 45642   score: 0.0   memory length: 44122   epsilon: 1.0   steps: 120   lr: 0.0005   reward MA: 0.76   mean loss: 0   mean max Q: nan
# episode: 305   frame: 45790   score: 1.0   memory length: 44265   epsilon: 1.0   steps: 148   lr: 0.0005   reward MA: 0.76   mean loss: 0   mean max Q: nan
# episode: 306   frame: 45910   score: 0.0   memory length: 44380   epsilon: 1.0   steps: 120   lr: 0.0005   reward MA: 0.76   mean loss: 0   mean max Q: nan
# episode: 307   frame: 46078   score: 1.0   memory length: 44543   epsilon: 1.0   steps: 168   lr: 0.0005   reward MA: 0.78   mean loss: 0   mean max Q: nan
# episode: 308   frame: 46226   score: 1.0   memory length: 44686   epsilon: 1.0   steps: 148   lr: 0.0005   reward MA: 0.76   mean loss: 0   mean max Q: nan
# ...
# episode: 141   frame: 71242   score: 0.0   memory length: 68872   epsilon: 0.96176   steps: 120   lr: 0.0005   reward MA: 1.0   mean loss: 0.07485   mean max Q: 0.26
# [PER DEBUG] Sampled TD-errors (first 5): [0.0885911, 0.11008781, 0.15856959, 0.18799254, 0.13912643]
# [PER DEBUG] Sampled TD-errors (first 5): [0.12890334, 0.32392988, 0.48961532, 0.3634201, 0.12488943]
# episode: 142   frame: 71420   score: 2.0   memory length: 69045   epsilon: 0.96144   steps: 178   lr: 0.0005   reward MA: 1.04   mean loss: 0.07224   mean max Q: 0.2637
# [PER DEBUG] Sampled TD-errors (first 5): [0.021109313, 0.18093552, 0.37646583, 0.5034486, 0.17693372]
# episode: 143   frame: 71588   score: 1.0   memory length: 69208   epsilon: 0.96114   steps: 168   lr: 0.0005   reward MA: 1.06   mean loss: 0.07225   mean max Q: 0.2696
# [PER DEBUG] Sampled TD-errors (first 5): [0.28364325, 0.4680685, 0.9957068, 0.9959502, 0.30605376]
# episode: 144   frame: 71708   score: 0.0   memory length: 69323   epsilon: 0.96092   steps: 120   lr: 0.0005   reward MA: 1.06   mean loss: 0.07379   mean max Q: 0.2748
# [PER DEBUG] Sampled TD-errors (first 5): [0.4662203, 0.20487395, 0.096098945, 0.35100368, 0.3763904]
# episode: 145   frame: 71856   score: 1.0   memory length: 69466   epsilon: 0.96066   steps: 148   lr: 0.0005   reward MA: 1.08   mean loss: 0.07198   mean max Q: 0.2635
# episode: 146   frame: 72004   score: 1.0   memory length: 69609   epsilon: 0.96039   steps: 148   lr: 0.0005   reward MA: 0.94   mean loss: 0.07292   mean max Q: 0.2705
# [PER DEBUG] Sampled TD-errors (first 5): [0.5064425, 0.22795641, 0.31642202, 1.2347581, 0.21543315]
# episode: 147   frame: 72173   score: 1.0   memory length: 69773   epsilon: 0.96009   steps: 169   lr: 0.0005   reward MA: 0.96   mean loss: 0.07093   mean max Q: 0.2783
# [DEBUG] Q-values: [[-0.23432204 -0.23687321  0.14533521]] mean: -0.10862001031637192 std: 0.21993538737297058 max: 0.14533521234989166
# [PER DEBUG] Sampled TD-errors (first 5): [0.21499258, 0.33151984, 0.38019922, 0.24994236, 0.041245937]
# episode: 148   frame: 72293   score: 0.0   memory length: 69888   epsilon: 0.95987   steps: 120   lr: 0.0005   reward MA: 0.92   mean loss: 0.07246   mean max Q: 0.2736
# episode: 149   frame: 72413   score: 0.0   memory length: 70003   epsilon: 0.95965   steps: 120   lr: 0.0005   reward MA: 0.9   mean loss: 0.07401   mean max Q: 0.2669
# [PER DEBUG] Sampled TD-errors (first 5): [1.0, 0.26356566, 0.21467231, 0.09281354, 0.08110589]
# episode: 150   frame: 72533   score: 0.0   memory length: 70118   epsilon: 0.95944   steps: 120   lr: 0.0005   reward MA: 0.9   mean loss: 0.07258   mean max Q: 0.2747
# [SAVED PLOT] ./save_graph/run16/Run16_StdDQN_750Kfr_timediff_new_get_frame_PER_ep150_scores.png
# [SAVED PLOT] ./save_graph/run16/Run16_StdDQN_750Kfr_timediff_new_get_frame_PER_ep150_losses.png
# [SAVED PLOT] ./save_graph/run16/Run16_StdDQN_750Kfr_timediff_new_get_frame_PER_ep150_Qstats.png
# [PLOT DEBUG] Last 5 q_means: [-0.12033643199416748, -0.12038712613804825, -0.12047549264401185, -0.12076679127807406, -0.12081724286065776]
# [PER DEBUG] Sampled TD-errors (first 5): [0.49639916, 0.40061316, 0.1797162, 0.43952602, 0.53798145]
# episode: 151   frame: 72789   score: 4.0   memory length: 70369   epsilon: 0.95898   steps: 256   lr: 0.0005   reward MA: 0.96   mean loss: 0.06993   mean max Q: 0.2679
# episode: 152   frame: 72909   score: 0.0   memory length: 70484   epsilon: 0.95876   steps: 120   lr: 0.0005   reward MA: 0.92   mean loss: 0.07154   mean max Q: 0.276
# episode: 153   frame: 73029   score: 0.0   memory length: 70599   epsilon: 0.95855   steps: 120   lr: 0.0005   reward MA: 0.88   mean loss: 0.07202   mean max Q: 0.2689
# [PER DEBUG] Sampled TD-errors (first 5): [0.09896627, 1.108853, 0.45264944, 0.38440904, 0.21267858]
# [PER DEBUG] Sampled TD-errors (first 5): [0.23793523, 0.48830748, 0.26688632, 0.086144164, 0.18376096]
# episode: 154   frame: 73206   score: 2.0   memory length: 70771   epsilon: 0.95823   steps: 177   lr: 0.0005   reward MA: 0.92   mean loss: 0.07241   mean max Q: 0.268
# [DEBUG] Q-values: [[ 0.0466996  -0.13692683  0.16664807]] mean: 0.025473615154623985 std: 0.15289649367332458 max: 0.16664807498455048
# [PER DEBUG] Sampled TD-errors (first 5): [0.26718423, 0.17528594, 0.26894426, 0.29956433, 0.46891755]
# episode: 155   frame: 73326   score: 0.0   memory length: 70886   epsilon: 0.95801   steps: 120   lr: 0.0005   reward MA: 0.92   mean loss: 0.07038   mean max Q: 0.2673
# episode: 156   frame: 73474   score: 1.0   memory length: 71029   epsilon: 0.95774   steps: 148   lr: 0.0005   reward MA: 0.92   mean loss: 0.07111   mean max Q: 0.2703
# episode: 157   frame: 73622   score: 1.0   memory length: 71172   epsilon: 0.95748   steps: 148   lr: 0.0005   reward MA: 0.94   mean loss: 0.07168   mean max Q: 0.2704
# [PER DEBUG] Sampled TD-errors (first 5): [0.38618642, 0.30435705, 0.2600516, 0.28715038, 0.09090966]
# episode: 158   frame: 73742   score: 0.0   memory length: 71287   epsilon: 0.95726   steps: 120   lr: 0.0005   reward MA: 0.92   mean loss: 0.07195   mean max Q: 0.2647
# [DEBUG] Q-values: [[-0.11132573 -0.38951573  0.1732016 ]] mean: -0.10921328514814377 std: 0.2813646197319031 max: 0.17320160567760468
# [PER DEBUG] Sampled TD-errors (first 5): [0.2780443, 0.14039524, 0.37141448, 0.26984462, 0.3462543]
# episode: 159   frame: 73862   score: 0.0   memory length: 71402   epsilon: 0.95705   steps: 120   lr: 0.0005   reward MA: 0.9   mean loss: 0.07225   mean max Q: 0.2746
# [PER DEBUG] Sampled TD-errors (first 5): [0.10406855, 0.4847868, 0.39662135, 0.32828626, 0.45846337]
# episode: 160   frame: 74010   score: 1.0   memory length: 71545   epsilon: 0.95678   steps: 148   lr: 0.0005   reward MA: 0.86   mean loss: 0.07267   mean max Q: 0.2675
# episode: 161   frame: 74188   score: 2.0   memory length: 71718   epsilon: 0.95646   steps: 178   lr: 0.0005   reward MA: 0.84   mean loss: 0.07339   mean max Q: 0.2694
# episode: 162   frame: 74308   score: 0.0   memory length: 71833   epsilon: 0.95624   steps: 120   lr: 0.0005   reward MA: 0.84   mean loss: 0.07215   mean max Q: 0.2707
# [DEBUG] Q-values: [[-0.04039421 -0.19281518  0.05899872]] mean: -0.05807022377848625 std: 0.12683410942554474 max: 0.058998722583055496
# episode: 163   frame: 74428   score: 0.0   memory length: 71948   epsilon: 0.95603   steps: 120   lr: 0.0005   reward MA: 0.82   mean loss: 0.07565   mean max Q: 0.2751
# [PER DEBUG] Sampled TD-errors (first 5): [0.17573908, 0.3798247, 0.24089907, 0.106082514, 0.20187223]
# episode: 164   frame: 74576   score: 1.0   memory length: 72091   epsilon: 0.95576   steps: 148   lr: 0.0005   reward MA: 0.8   mean loss: 0.07331   mean max Q: 0.2704
# [DEBUG] Q-values: [[-0.07376115 -0.04619953  0.15747017]] mean: 0.01250316109508276 std: 0.126299187541008 max: 0.15747016668319702
# episode: 165   frame: 74754   score: 2.0   memory length: 72264   epsilon: 0.95544   steps: 178   lr: 0.0005   reward MA: 0.82   mean loss: 0.07305   mean max Q: 0.2696
# episode: 166   frame: 74902   score: 1.0   memory length: 72407   epsilon: 0.95517   steps: 148   lr: 0.0005   reward MA: 0.84   mean loss: 0.07329   mean max Q: 0.2756
# Target network updated at frame:  75000
# [PER DEBUG] Sampled TD-errors (first 5): [0.51697683, 0.36155468, 0.24803379, 0.25872838, 0.3193675]
# [DEBUG] Q-values: [[-0.06138286 -0.11442391  0.08412509]] mean: -0.030560558661818504 std: 0.10280046612024307 max: 0.0841250866651535
# [DEBUG] Q-values: [[-0.10986668 -0.28369573  0.08872542]] mean: -0.10161232948303223 std: 0.18634775280952454 max: 0.08872541785240173
# episode: 167   frame: 75050   score: 1.0   memory length: 72550   epsilon: 0.95491   steps: 148   lr: 0.0005   reward MA: 0.86   mean loss: 0.0729   mean max Q: 0.2737
# [DEBUG] Q-values: [[-0.10917261 -0.21168539  0.0507822 ]] mean: -0.09002526849508286 std: 0.13227726519107819 max: 0.05078219994902611
# episode: 168   frame: 75198   score: 1.0   memory length: 72693   epsilon: 0.95464   steps: 148   lr: 0.0005   reward MA: 0.88   mean loss: 0.07049   mean max Q: 0.2631
# [PER DEBUG] Sampled TD-errors (first 5): [0.1348898, 0.26204246, 0.09239117, 0.31740522, 0.2615256]
# episode: 169   frame: 75379   score: 2.0   memory length: 72869   epsilon: 0.95432   steps: 181   lr: 0.0005   reward MA: 0.92   mean loss: 0.07117   mean max Q: 0.2752
# episode: 170   frame: 75499   score: 0.0   memory length: 72984   epsilon: 0.9541   steps: 120   lr: 0.0005   reward MA: 0.92   mean loss: 0.07127   mean max Q: 0.2703
# episode: 171   frame: 75647   score: 1.0   memory length: 73127   epsilon: 0.95383   steps: 148   lr: 0.0005   reward MA: 0.94   mean loss: 0.07233   mean max Q: 0.2772
# episode: 172   frame: 75767   score: 0.0   memory length: 73242   epsilon: 0.95362   steps: 120   lr: 0.0005   reward MA: 0.9   mean loss: 0.0744   mean max Q: 0.2691
# [PER DEBUG] Sampled TD-errors (first 5): [0.17566192, 0.3903303, 0.20148773, 0.65358555, 1.200077]
# episode: 173   frame: 75915   score: 1.0   memory length: 73385   epsilon: 0.95335   steps: 148   lr: 0.0005   reward MA: 0.92   mean loss: 0.07348   mean max Q: 0.2732
# episode: 174   frame: 76035   score: 0.0   memory length: 73500   epsilon: 0.95314   steps: 120   lr: 0.0005   reward MA: 0.9   mean loss: 0.07337   mean max Q: 0.2804
# [DEBUG] Q-values: [[-0.1613957  -0.18102926 -0.02713486]] mean: -0.1231866106390953 std: 0.08376050740480423 max: -0.027134861797094345
# episode: 175   frame: 76155   score: 0.0   memory length: 73615   epsilon: 0.95292   steps: 120   lr: 0.0005   reward MA: 0.9   mean loss: 0.07292   mean max Q: 0.2756
# [SAVED PLOT] ./save_graph/run16/Run16_StdDQN_750Kfr_timediff_new_get_frame_PER_ep175_Qstats.png
# [PLOT DEBUG] Last 5 q_means: [-0.12010117214325192, -0.12009886351876578, -0.12015220897357219, -0.12014560645850003, -0.12021946225021533]
# episode: 176   frame: 76275   score: 0.0   memory length: 73730   epsilon: 0.9527   steps: 120   lr: 0.0005   reward MA: 0.86   mean loss: 0.07245   mean max Q: 0.2683
# episode: 177   frame: 76395   score: 0.0   memory length: 73845   epsilon: 0.95249   steps: 120   lr: 0.0005   reward MA: 0.86   mean loss: 0.07041   mean max Q: 0.2724
# episode: 178   frame: 76515   score: 0.0   memory length: 73960   epsilon: 0.95227   steps: 120   lr: 0.0005   reward MA: 0.86   mean loss: 0.07351   mean max Q: 0.2708
# episode: 179   frame: 76635   score: 0.0   memory length: 74075   epsilon: 0.95206   steps: 120   lr: 0.0005   reward MA: 0.84   mean loss: 0.07112   mean max Q: 0.2608
# episode: 180   frame: 76783   score: 1.0   memory length: 74218   epsilon: 0.95179   steps: 148   lr: 0.0005   reward MA: 0.86   mean loss: 0.07124   mean max Q: 0.2707
# [DEBUG] Q-values: [[-0.02642459  0.03211971  0.03542307]] mean: 0.01370606105774641 std: 0.034793391823768616 max: 0.03542306646704674
# episode: 181   frame: 76931   score: 1.0   memory length: 74361   epsilon: 0.95152   steps: 148   lr: 0.0005   reward MA: 0.88   mean loss: 0.07188   mean max Q: 0.2657
# episode: 182   frame: 77099   score: 1.0   memory length: 74524   epsilon: 0.95122   steps: 168   lr: 0.0005   reward MA: 0.9   mean loss: 0.06996   mean max Q: 0.2679
# episode: 183   frame: 77277   score: 2.0   memory length: 74697   epsilon: 0.9509   steps: 178   lr: 0.0005   reward MA: 0.9   mean loss: 0.07066   mean max Q: 0.2678
# [PER DEBUG] Sampled TD-errors (first 5): [0.4181453, 0.17205583, 0.120157674, 0.3687947, 0.27486673]
# episode: 184   frame: 77397   score: 0.0   memory length: 74812   epsilon: 0.95068   steps: 120   lr: 0.0005   reward MA: 0.82   mean loss: 0.07555   mean max Q: 0.2724
# episode: 185   frame: 77593   score: 2.0   memory length: 75003   epsilon: 0.95033   steps: 196   lr: 0.0005   reward MA: 0.8   mean loss: 0.07237   mean max Q: 0.274
# episode: 186   frame: 77873   score: 5.0   memory length: 75278   epsilon: 0.94983   steps: 280   lr: 0.0005   reward MA: 0.9   mean loss: 0.07285   mean max Q: 0.2738
# episode: 187   frame: 77993   score: 0.0   memory length: 75393   epsilon: 0.94961   steps: 120   lr: 0.0005   reward MA: 0.84   mean loss: 0.07259   mean max Q: 0.2695
# episode: 188   frame: 78141   score: 1.0   memory length: 75536   epsilon: 0.94934   steps: 148   lr: 0.0005   reward MA: 0.84   mean loss: 0.07454   mean max Q: 0.2657
# episode: 189   frame: 78261   score: 0.0   memory length: 75651   epsilon: 0.94913   steps: 120   lr: 0.0005   reward MA: 0.84   mean loss: 0.07477   mean max Q: 0.2723
# [DEBUG] Q-values: [[-0.19798754 -0.39174664 -0.09967431]] mean: -0.22980283200740814 std: 0.14861266314983368 max: -0.09967431426048279
# episode: 190   frame: 78409   score: 1.0   memory length: 75794   epsilon: 0.94886   steps: 148   lr: 0.0005   reward MA: 0.82   mean loss: 0.07373   mean max Q: 0.2695
# episode: 191   frame: 78557   score: 1.0   memory length: 75937   epsilon: 0.9486   steps: 148   lr: 0.0005   reward MA: 0.84   mean loss: 0.07236   mean max Q: 0.2668
# episode: 192   frame: 78705   score: 1.0   memory length: 76080   epsilon: 0.94833   steps: 148   lr: 0.0005   reward MA: 0.82   mean loss: 0.07093   mean max Q: 0.2749
# [DEBUG] Q-values: [[-0.4725464  -0.07803281 -0.05092044]] mean: -0.20049987733364105 std: 0.23598888516426086 max: -0.05092044174671173
# episode: 193   frame: 78825   score: 0.0   memory length: 76195   epsilon: 0.94811   steps: 120   lr: 0.0005   reward MA: 0.8   mean loss: 0.07243   mean max Q: 0.2723
# episode: 194   frame: 78973   score: 1.0   memory length: 76338   epsilon: 0.94785   steps: 148   lr: 0.0005   reward MA: 0.82   mean loss: 0.07079   mean max Q: 0.2694
# [DEBUG] Q-values: [[-0.31957895 -0.34522933  0.00240714]] mean: -0.22080038487911224 std: 0.19372837245464325 max: 0.0024071354418992996
# [DEBUG] Q-values: [[-0.23937738 -0.17335236  0.00612907]] mean: -0.13553355634212494 std: 0.12704743444919586 max: 0.006129072979092598
# [DEBUG] Q-values: [[-0.07667844 -0.26295155  0.20279108]] mean: -0.04561297222971916 std: 0.23442023992538452 max: 0.20279107987880707
# episode: 195   frame: 79093   score: 0.0   memory length: 76453   epsilon: 0.94763   steps: 120   lr: 0.0005   reward MA: 0.8   mean loss: 0.07068   mean max Q: 0.2667
# episode: 196   frame: 79259   score: 1.0   memory length: 76614   epsilon: 0.94733   steps: 166   lr: 0.0005   reward MA: 0.8   mean loss: 0.07054   mean max Q: 0.2666
# episode: 197   frame: 79379   score: 0.0   memory length: 76729   epsilon: 0.94712   steps: 120   lr: 0.0005   reward MA: 0.78   mean loss: 0.07165   mean max Q: 0.2746
# episode: 198   frame: 79499   score: 0.0   memory length: 76844   epsilon: 0.9469   steps: 120   lr: 0.0005   reward MA: 0.78   mean loss: 0.07318   mean max Q: 0.266
# episode: 199   frame: 79619   score: 0.0   memory length: 76959   epsilon: 0.94668   steps: 120   lr: 0.0005   reward MA: 0.78   mean loss: 0.07283   mean max Q: 0.2713
# [PER DEBUG] Sampled TD-errors (first 5): [0.33389392, 0.33573157, 0.21328723, 0.43092328, 0.38216177]
# episode: 200   frame: 79739   score: 0.0   memory length: 77074   epsilon: 0.94647   steps: 120   lr: 0.0005   reward MA: 0.78   mean loss: 0.07038   mean max Q: 0.2665
# [PER STATS] TD-error mean: 0.29837004917335225 std: 0.31772801371596976 min: 7.152557373046875e-07 max: 4.064648628234863
# [SAVED PLOT] ./save_graph/run16/Run16_StdDQN_750Kfr_timediff_new_get_frame_PER_ep200_scores.png
# [SAVED PLOT] ./save_graph/run16/Run16_StdDQN_750Kfr_timediff_new_get_frame_PER_ep200_losses.png
# [SAVED PLOT] ./save_graph/run16/Run16_StdDQN_750Kfr_timediff_new_get_frame_PER_ep200_Qstats.png
# [PLOT DEBUG] Last 5 q_means: [-0.12038282032928042, -0.12032732425129586, -0.12035605759441674, -0.1204091653949998, -0.12042513581536063]
# episode: 201   frame: 79887   score: 1.0   memory length: 77217   epsilon: 0.9462   steps: 148   lr: 0.0005   reward MA: 0.72   mean loss: 0.06924   mean max Q: 0.2693
# Target network updated at frame:  80000
# episode: 202   frame: 80007   score: 0.0   memory length: 77332   epsilon: 0.94599   steps: 120   lr: 0.0005   reward MA: 0.72   mean loss: 0.07173   mean max Q: 0.2747

# %%
# End logging
sys.stdout = tee.ipython_stdout
tee.close()

# %%
# metadata = create_metadata(agent, 1879, frame, evaluation_reward, rewards, episodes, losses_window, loss_history)
# agent.save_checkpoint(metadata, run_name, 1879)
# agent.save_replay_buffer(run_name, frame)

# %%
print(episodes)

# %%
import pylab
import os

pylab.plot(episodes, rewards, 'b')
pylab.xlabel('Episode #')
pylab.ylabel('Rolling Mean Episode Scores')

# Main title
pylab.text(0.5, 1.05, 'Std DQN Scores',
           ha='center', va='bottom', transform=pylab.gca().transAxes,
           fontsize=14, fontweight='semibold')

# Subtitle (smaller font)
pylab.text(0.5, 1.01, '(750K training steps)',
           ha='center', va='bottom', transform=pylab.gca().transAxes,
           fontsize=10, color='gray')

plot_path = f"./presentation_assets/DQN_750K_steps_SCORES.png"
os.makedirs(os.path.dirname(plot_path), exist_ok=True)
pylab.savefig(plot_path, bbox_inches='tight')
print(f"[SAVED PLOT] {plot_path}")
pylab.show()
pylab.close()
# Out:
# [SAVED PLOT] ./presentation_assets/DQN_750K_steps_SCORES.png

# %%
# === Load checkpoint files ===
ddqn_ckpt = torch.load("./checkpoints/Run12_DDQN_750K_frames_imprvdBatching_3007_checkpoint.pt")
dqn_ckpt  = torch.load("./checkpoints/Run13_StdDQN_750K_frames_imprvdBatching_2673_checkpoint.pt")

# === Extract metadata ===
ddqn_meta = ddqn_ckpt["metadata"]
dqn_meta = dqn_ckpt["metadata"]

# # === Extract episode indices and rolling mean rewards ===
# ddqn_episodes = ddqn_meta["episodes"]
# ddqn_rewards = ddqn_meta["rewards"]

# dqn_episodes = dqn_meta["episodes"]
# dqn_rewards = dqn_meta["rewards"]

# # === Plot ===
# plt.figure(figsize=(10, 6))
# plt.plot(dqn_episodes, dqn_rewards, label="DQN", color="red")
# plt.plot(ddqn_episodes, ddqn_rewards, label="DDQN", color="blue")
# plt.xlabel("Episode #", fontweight="bold")
# plt.ylabel("Mean Episode Score (Moving Avg)", fontweight="bold")
# plt.legend(loc = "upper left")
# # Main title
# pylab.text(0.5, 1.05, 'Std DQN vs DDQN Scores',
#            ha='center', va='bottom', transform=pylab.gca().transAxes,
#            fontsize=14, fontweight='semibold')

# # Subtitle (smaller font)
# pylab.text(0.5, 1.01, '(750K training steps)',
#            ha='center', va='bottom', transform=pylab.gca().transAxes,
#            fontsize=10, color='gray')


# plot_path = f"./presentation_assets/DQN_vs_DDQN_750K_steps_SCORES.png"
# os.makedirs(os.path.dirname(plot_path), exist_ok=True)
# pylab.savefig(plot_path, bbox_inches='tight')
# print(f"[SAVED PLOT] {plot_path}")
# plt.show()


# # === Extract loss data ===
ddqn_loss_history = ddqn_meta["loss_tracker"]
dqn_loss_history = dqn_meta["loss_tracker"]

ddqn_episodes = [entry[1] for entry in ddqn_loss_history]
ddqn_losses = [entry[0] for entry in ddqn_loss_history]

dqn_episodes = [entry[1] for entry in dqn_loss_history]
dqn_losses = [entry[0] for entry in dqn_loss_history]

# === Plot ===
plt.figure(figsize=(10, 6))
plt.plot(dqn_episodes, dqn_losses, label="DQN", color="red")
plt.plot(ddqn_episodes, ddqn_losses, label="DDQN", color="blue")
plt.xlabel("Episode #", fontweight="bold")
plt.ylabel("Mean Episode Loss (Moving Avg)", fontweight="bold")
plt.legend(loc = "best")
# Main title
pylab.text(0.5, 1.05, 'Std DQN vs DDQN Huber Loss',
           ha='center', va='bottom', transform=pylab.gca().transAxes,
           fontsize=14, fontweight='semibold')

# Subtitle (smaller font)
pylab.text(0.5, 1.01, '(750K training steps)',
           ha='center', va='bottom', transform=pylab.gca().transAxes,
           fontsize=10, color='gray')


plot_path = f"./presentation_assets/DQN_vs_DDQN_750K_steps_LOSSES.png"
os.makedirs(os.path.dirname(plot_path), exist_ok=True)
pylab.savefig(plot_path, bbox_inches='tight')
print(f"[SAVED PLOT] {plot_path}")
plt.show()
# Out:
# C:\Users\rbisk\AppData\Local\Temp\ipykernel_175372\762919505.py:2: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   ddqn_ckpt = torch.load("./checkpoints/Run12_DDQN_750K_frames_imprvdBatching_3007_checkpoint.pt")
# C:\Users\rbisk\AppData\Local\Temp\ipykernel_175372\762919505.py:3: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   dqn_ckpt  = torch.load("./checkpoints/Run13_StdDQN_750K_frames_imprvdBatching_2673_checkpoint.pt")
# [SAVED PLOT] ./presentation_assets/DQN_vs_DDQN_750K_steps_LOSSES.png

# %%
# chkpt = torch.load("./checkpoints/Run12_DDQN_750K_frames_imprvdBatching_3007_checkpoint.pt")
from model import DQN_DualBranch
action_size = len(TRAINABLE_ACTIONS)
model = DQN_DualBranch(action_size)
model.eval()

#create dummy input for model
dummy_input = torch.rand(BATCH_SIZE, 6, 84, 84)

#export to ONNX
torch.onnx.export(model, dummy_input, "Branched Network.onnx",
                  input_names=["input"], output_names=["output"],
                  dynamic_axes={"input": {0: "batch_size"}, "output": {0: "batch_size"}},
                  opset_version=11)

print("ONNX model exported successfully!")
# Out:
# ONNX model exported successfully!

# %% [markdown]
# ## Timediff Frames

# %% [markdown]
# Instead of using a 4 frame history to train the model, here we will feed the model the 4 frames plus the "diff" between each of the 4 frames to help isolate the ball position which is the most important thing for the model to learn

# %% [markdown]
# # Visualize Agent Performance

# %% [markdown]
# BE AWARE THIS CODE BELOW MAY CRASH THE KERNEL IF YOU RUN THE SAME CELL TWICE.
#
# Please save your model before running this portion of the code.

# %%
# torch.save(agent.policy_net, "./save_model/breakout_dqn_latest.pth")

# %% [markdown]
# ### Play Game in Window or Save Video

# %%
import gymnasium as gym
from gymnasium.wrappers import RecordVideo

# set random seed to sync visual and recorded game
seed = 55
np.random.seed(seed)
random.seed(seed)
torch.manual_seed(seed)

# Load and setup Agent
print("Instantiating agent")
agent = Agent(action_size)
agent.load_policy_net("./save_model/run3/good_Run3_DDQN_Serial_InvTimeEpsilon_ddqn_886_eps.pth")
agent.policy_net.eval()
agent.epsilon = 0  # Set agent to only exploit the best action


# Create environments
env_human = gym.make('ALE/Breakout-v5', frameskip=4, repeat_action_probability=sticky_action_prob, full_action_space=False, render_mode="human")
# env_record = RecordVideo(env_record, video_folder="./videos", episode_trigger=lambda e: True)

# Reset to seed
state_h, _ = env_human.reset(seed=seed)
state_h = do_random_actions(env_human, 20)


# Setup History
history = np.zeros([HISTORY_SIZE + 1, 84, 84], dtype=np.uint8)
get_init_state(history, state_h, HISTORY_SIZE)

done = False
fire_ready = True
life = number_lives
score = 0
step = 0

while not done:
    step += 1

    # Select action
    if fire_ready:
        print(f"[DEBUG] Agent is not acting — sending FIRE at step {step}")
        action = 1
        fire_ready = False
    else:
        model_action = agent.get_action(np.float32(history[:4, :, :]) / 255.)
        action = TRAINABLE_ACTIONS[model_action]

    # Step the environment
    state_h, reward, term_h, trunc_h, info = env_human.step(action)
    done = term_h or trunc_h

    # update history
    frame_next_state = get_frame(state_h)
    history[4, :, :] = frame_next_state
    history[:4, :, :] = history[1:, :, :]  #shift history by one erasing oldest frame
    
    # check if life has been lost
    lost_life = check_live(life, info['lives'])  #check if the agent has lost a life
    if lost_life:
        print(f"[DEBUG] Lost life detected at step {step}")
        fire_ready = True
    life = info['lives']
    
    # keep track of score
    score += reward # update total score

    
env_human.close()

# %% [markdown]
# ### Play Game Rendered in Jupyter Notebook

# %%
from IPython.display import display as ipythondisplay, clear_output

def show_state_live(frame, step=0, info=""):
    plt.figure(3)
    plt.clf()
    plt.imshow(frame)
    plt.title(f"Step: {step} {info}")
    plt.axis('off')
    clear_output(wait=True)
    ipythondisplay(plt.gcf())

# %%
import gymnasium as gym
from gymnasium.wrappers import RecordVideo


# set random seed to sync visual and recorded game
seed = 42
np.random.seed(seed)
random.seed(seed)
torch.manual_seed(seed)

# Load and setup Agent
# Choose whether to use double DQN
double_dqn = False # set to True if using double DQN agent
if double_dqn:
    from agent_double import Agent
else:
    from agent import Agent

#Initialize agent
print("Instantiating agent")
agent = Agent(action_size)
agent.load_policy_net("./save_model/Run1_serial/good_breakout_dqn_1256_eps.pth")
agent.policy_net.eval()
agent.epsilon = 0  # Set agent to only exploit the best action


# Create environments
env = gym.make('ALE/Breakout-v5', frameskip=4, repeat_action_probability=sticky_action_prob, full_action_space=False, render_mode="rgb_array")
# Use RecordVideo to save the video to the "videos" directory
# env = RecordVideo(env, video_folder="./videos", episode_trigger=lambda episode_id: True)

# Reset the environment
state, _ = env.reset(seed=seed)

# Setup History
history = np.zeros([HISTORY_SIZE + 1, 84, 84], dtype=np.uint8)
get_init_state(history, state, HISTORY_SIZE)

#Initialize variables
step = 0
done = False
fire_ready = True
life = number_lives
score = 0

while not done:

    # Render the current frame live in the notebook
    show_state_live(state, step)   

    # Select action
    if fire_ready:
        action = 1
        fire_ready = False
    else:
        model_action = agent.get_action(np.float32(history[:4, :, :]) / 255.)
        action = TRAINABLE_ACTIONS[model_action]

    # Step the environment
    next_state, reward, term, trunc, info = env.step(action)
    done = term or trunc

    # update history
    frame_next_state = get_frame(state)
    history[4, :, :] = frame_next_state
    history[:4, :, :] = history[1:, :, :]  #shift history by one erasing oldest frame
    
    # check if life has been lost
    lost_life = check_live(life, info['lives'])  #check if the agent has lost a life
    if lost_life:
        fire_ready = True  
        # do_random_actions(env_human, 30) #IMPT: introduce randomness to game and paddle position before next life
    life = info['lives']
    
    # keep track of score
    score += reward # update total score

    state = next_state
    step += 1

    

env.close()

# %% [markdown]
# ## Model Comparison Tester

# %%
import gymnasium as gym



# set random seed to sync visual and recorded game
seed = 42
np.random.seed(seed)
random.seed(seed)
torch.manual_seed(seed)

# Load and setup Agent
# Choose whether to use double DQN
double_dqn = False # set to True if using double DQN agent
if double_dqn:
    from agent_double import Agent
else:
    from agent import Agent

def set_global_seed(seed):
    np.random.seed(seed)
    random.seed(seed)
    torch.manual_seed(seed)

# 20 unique, fixed seeds
seeds = [42, 7, 99, 123, 88, 33, 11, 55, 3, 77,
        18, 29, 71, 64, 5, 101, 202, 404, 999, 83]


#Initialize agent
print("Instantiating agent")
agent = Agent(action_size)
agent.load_policy_net("./save_model/Run1_serial/good_breakout_dqn_1256_eps.pth")
agent.policy_net.eval()
agent.epsilon = 0.05  # Set agent to use model action 95% of the time for robustness


# Create environments
env = gym.make('ALE/Breakout-v5', frameskip=4, repeat_action_probability=sticky_action_prob, full_action_space=False, render_mode="rgb_array")
# Use RecordVideo to save the video to the "videos" directory
# env = RecordVideo(env, video_folder="./videos", episode_trigger=lambda episode_id: True)

scores = []

for seed in seeds:
    set_global_seed(seed)
    # Reset the environment
    state, _ = env.reset(seed=seed)

    # Setup History
    history = np.zeros([HISTORY_SIZE + 1, 84, 84], dtype=np.uint8)
    get_init_state(history, state, HISTORY_SIZE)

    #Initialize variables
    step = 0
    done = False
    fire_ready = True
    life = number_lives
    score = 0

    while not done:
        
        # Selet Action (with robust check for FIRE action)
        if fire_ready:
            next_state, force_done = reset_after_life_loss(env, history)
            if force_done:
                break
            action = 1
            fire_ready = False
        else:
            trainable_action = agent.get_action(np.float32(history[:4, :, :]) / 255.)
            action = TRAINABLE_ACTIONS[trainable_action]

        # Step the environment
    
        next_state, reward, term, trunc, info = env.step(action)
        done = term or trunc
        # update total score
        score += reward 

        # update history
        history[4, :, :] = get_frame(next_state)  #append new frame to history
        history[:4, :, :] = history[1:, :, :]  #shift history by one erasing oldest frame
        
        # check if life has been lost
        lost_life = check_live(life, info['lives'])  #check if the agent has lost a life
        if lost_life:
            fire_ready = True  
        life = info['lives']
        
        
        step += 1
    
    scores.append(score)

env.close()
print("Mean Score: ", np.mean(scores))
print("Std Score: ", np.std(scores))
print("Max Score: ", np.max(scores))
print("Min Score: ", np.min(scores))
print("Median Score: ", np.median(scores))

        

env.close()

# %% [markdown]
# ## SCRATCH

# %%
for i in range(4):
    print(i)

# %%
env = gym.make('ALE/Breakout-v5', frameskip=4, repeat_action_probability=0.0, full_action_space=False)
env.reset()
next_state, reward, terminations, truncations, info = env.step(torch.tensor([[1]]))
done = truncations or terminations
print("reward: ", reward)
print("done: ", done)
print("info: ", info)
print(next_state.shape)

# %%
print(env.action_space)
print("Expected type:", type(env.action_space.sample()))

# %%
print("agent memory type: ", type(agent.memory.memory[0]))
print("agent memory[0]: ", agent.memory.memory[0])

# %%
print("Cell 1")
# Out:
# Cell 1

# %%
print("Cell 2")
